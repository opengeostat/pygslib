# %% [markdown]
# ## Testing nonlinear

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as plt
import pygslib as gslib
# %matplotlib inline
from scipy.stats import norm

# %% [markdown]
# ## Get some data ready for work

# %%
#get the raw data in gslib format into a pandas Dataframe
mydata= gslib.read_gslib_file('../datasets/cluster.dat')
transin,transout, error = gslib.__dist_transf.ns_ttable(mydata['Primary'],mydata['Declustering Weight'])
mydata['NS_Primary'] = gslib.__dist_transf.nscore(mydata['Primary'],transin,transout,getrank=False)
print 'there was any error?: ', error!=0

# this is sampling regularly the probability space
gmin=norm.cdf(transout.min())
gmax=norm.cdf(transout.max())
print gmin, gmax
g=np.linspace( gmin+0.001, gmax-0.001, 1000) 

# we get normal Y from probabilities
y=norm.ppf(g)

# and z is drow from back transfor algorithm
z,error = gslib.__dist_transf.backtr(y,transin,transout,
                                     ltail=1,utail=1,ltpar=0,utpar=60,
                                     zmin=transin.min(),zmax=transin.max(),getrank=False)

print 'there was any error?: ', error!=0, error
# make sure we are within the ranges
print mydata['NS_Primary'].min(),mydata['NS_Primary'].max()
print y.min(),y.max()
print z.min(),z.max()
print transin.min(),transin.max()
# Out:
# there was any error?:  False
# 0.00578201714828 0.998392892045
# there was any error?:  False 0
# -2.11193373101 2.94647193736
# -2.46860634208 2.79349299021
# 0.06 42.8688393913
# 0.06 58.32

# %% [markdown]
# ## Get transformation table

# %%
# we already have Z, Y

print y.mean(), y.var() # this is 0 an 1? 
print z.mean(), z.var() # this is around data mean and variance



J=np.isfinite(z)
 
for i in range(z.shape[0]-2,0,-1):
    if z[i]==z[i+1]:
        J[i+1]=False

y=y[J]
z=z[J]

#pd.DataFrame({'z':z,'y':y})
# Out:
# 0.0111497722827 0.936018018571
# 2.41482249451 14.2657249085

# %%
# plot experimental anamorphosis function 
plt.plot(y,z, label='raw or experimental')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Experimental Gaussian anamorphosis')
#plt.yscale ('log')
#plt.xscale ('log')
#plt.legend(loc=2)
plt.show()
pd.DataFrame({'y':y}).hist(bins=30)
plt.show()
pd.DataFrame({'z':z}).hist(bins=30)
plt.show()

# %% [markdown]
# ## Test anamorphosis

# %%
K=50
H=gslib.nonlinear.recurrentH(y=y, K=K)
# some test plot, example lack of correlation
plt.scatter(H[1,:], H[2,:])
plt.show()
plt.scatter(H[1,:], H[3,:])
plt.show()

print H.shape, y.shape

pd.DataFrame (H.T, columns=range(H.shape[0]))
# Out:
# /home/adrian/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# (51, 870) (870,)
#      0         1         2         3         4         5         6         7   \
# 0     1  2.468606  3.602014  3.118164  0.729324 -1.983801 -2.665062 -0.649981
# 1     1  2.419374  3.431852  2.818290  0.437178 -2.047738 -2.421650 -0.318610
# 2     1  2.103990  2.423096  1.225529 -0.809212 -1.857561 -0.856847  1.038374
# 3     1  2.081781  2.357361  1.133584 -0.861597 -1.816056 -0.756909  1.085776
# 4     1  2.060553  2.295183  1.048055 -0.907900 -1.774046 -0.663562  1.125655
# 5     1  2.040215  2.236209  0.968244 -0.948901 -1.731813 -0.576228  1.159001
# 6     1  2.020688  2.180136  0.893560 -0.985251 -1.689575 -0.494395  1.186649
# 7     1  2.001902  2.126701  0.823492 -1.017502 -1.647501 -0.417610  1.209306
# 8     1  1.983797  2.075676  0.757603 -1.046123 -1.605721 -0.345468  1.227575
# 9     1  1.966319  2.026859  0.695509 -1.071515 -1.564335 -0.277610  1.241974
# 10    1  1.949423  1.980076  0.636878 -1.094024 -1.523420 -0.213709  1.252949
# 11    1  1.933065  1.935169  0.581415 -1.113949 -1.483035 -0.153476  1.260889
# 12    1  1.917209  1.892000  0.528862 -1.131550 -1.443222 -0.096647  1.266130
# 13    1  1.901821  1.850444  0.478989 -1.147056 -1.404015 -0.042985  1.268967
# 14    1  1.886870  1.810392  0.431590 -1.160667 -1.365437  0.007728  1.269660
# 15    1  1.872330  1.771741  0.386483 -1.172560 -1.327503  0.055685  1.268436
# 16    1  1.858175  1.734402  0.343504 -1.182891 -1.290223  0.101068  1.265497
# 17    1  1.844383  1.698292  0.302503 -1.191799 -1.253602  0.144039  1.261021
# 18    1  1.830933  1.663338  0.263347 -1.199408 -1.217641  0.184748  1.255167
# 19    1  1.817806  1.629470  0.225914 -1.205828 -1.182339  0.223333  1.248078
# 20    1  1.804985  1.596627  0.190095 -1.211160 -1.147692  0.259920  1.239879
# 21    1  1.792455  1.564752  0.155788 -1.215493 -1.113693  0.294625  1.230683
# 22    1  1.780199  1.533791  0.122902 -1.218907 -1.080335  0.327558  1.220593
# 23    1  1.768205  1.503698  0.091352 -1.221476 -1.047609  0.358816  1.209701
# 24    1  1.650494  1.219145 -0.185883 -1.209210 -0.726288  0.614472  1.055737
# 25    1  1.640867  1.196739 -0.206026 -1.205437 -0.700296  0.631293  1.039869
# 26    1  1.631389  1.174809 -0.225491 -1.201346 -0.674792  0.647255  1.023838
# 27    1  1.622056  1.153336 -0.244310 -1.196961 -0.649764  0.662396  1.007666
# 28    1  1.612861  1.132305 -0.262509 -1.192300 -0.625203  0.676753  0.991377
# 29    1  1.603801  1.111698 -0.280116 -1.187384 -0.601098  0.690360  0.974991
# ..   ..       ...       ...       ...       ...       ...       ...       ...
# 840   1 -1.833733  1.670595 -0.271433 -1.197910  1.225148  0.176369 -1.256505
# 841   1 -1.847254  1.705787 -0.310966 -1.190038  1.261247  0.135196 -1.262081
# 842   1 -1.861121  1.742148 -0.352372 -1.180841  1.298007  0.091731 -1.266248
# 843   1 -1.875355  1.779756 -0.395786 -1.170194  1.335425  0.045821 -1.268842
# 844   1 -1.889979  1.818694 -0.441361 -1.157954  1.373496 -0.002700 -1.269681
# 845   1 -1.905019  1.859054 -0.489263 -1.143960  1.412208 -0.054016 -1.268557
# 846   1 -1.920503  1.900939 -0.539682 -1.128030  1.451544 -0.108326 -1.265237
# 847   1 -1.936462  1.944463 -0.592827 -1.109960  1.491480 -0.165850 -1.259454
# 848   1 -1.952930  1.989752 -0.648934 -1.089515  1.531981 -0.226832 -1.250906
# 849   1 -1.969945  2.036949 -0.708267 -1.066426  1.573000 -0.291539 -1.239244
# 850   1 -2.024730  2.191699 -0.908864 -0.977965  1.698447 -0.511168 -1.181272
# 851   1 -2.044422  2.248359 -0.984582 -0.940686  1.740700 -0.594118 -1.152489
# 852   1 -2.064940  2.307980 -1.065542 -0.898629  1.782906 -0.682672 -1.117842
# 853   1 -2.086366  2.370874 -1.152359 -0.851116  1.824836 -0.777355 -1.076470
# 854   1 -2.108795  2.437408 -1.245753 -0.797339  1.866191 -0.878759 -1.027343
# 855   1 -2.132338  2.508012 -1.346582 -0.736319  1.906580 -0.987559 -0.969230
# 856   1 -2.157126  2.583196 -1.455871 -0.666865  1.945493 -1.104522 -0.900641
# 857   1 -2.183314  2.663573 -1.574864 -0.587510  1.982251 -1.230527 -0.819758
# 858   1 -2.211092  2.749887 -1.705087 -0.496420  2.015951 -1.366580 -0.724338
# 859   1 -2.240688  2.843053 -1.848436 -0.391272  2.045372 -1.513838 -0.611576
# 860   1 -2.272388  2.944215 -2.007307 -0.269074  2.068835 -1.673625 -0.477922
# 861   1 -2.306551  3.054827 -2.184786 -0.125898  2.083998 -1.847459 -0.318803
# 862   1 -2.343639  3.176779 -2.384928  0.043534  2.087516 -2.037048 -0.128222
# 863   1 -2.384261  3.312585 -2.613210  0.246505  2.074484 -2.244269  0.101860
# 864   1 -2.429247  3.465699 -2.877262  0.493406  2.037469 -2.471047  0.382509
# 865   1 -2.479761  3.641046 -3.188135  0.799669  1.964735 -2.719011  0.729433
# 866   1 -2.537528  3.845989 -3.562656  1.189445  1.836733 -2.988558  1.165829
# 867   1 -2.605254  4.092272 -4.028186  1.703211  1.618499 -3.276232  1.727645
# 868   1 -2.687569  4.400345 -4.633487  2.415598  1.240968 -3.566713  2.474174
# 869   1 -2.793493  4.810874 -5.478215  3.485339  0.545673 -3.803970  3.511194
#
#            8         9     ...           41        42        43        44  \
# 0    1.925644  2.197360    ...    -0.158959  1.552547  0.741570 -1.258823
# 1    1.992714  1.907428    ...     0.325401  1.524205  0.240762 -1.418971
# 2    1.573925  0.124853    ...     0.857482 -0.491901 -1.005282  0.167415
# 3    1.507177  0.022192    ...     0.740994 -0.607068 -0.925052  0.309811
# 4    1.440762 -0.071688    ...     0.620871 -0.700829 -0.833831  0.433798
# 5    1.375028 -0.157599    ...     0.500060 -0.774750 -0.735259  0.539749
# 6    1.310231 -0.236261    ...     0.380851 -0.830513 -0.632321  0.628397
# 7    1.246560 -0.308315    ...     0.264996 -0.869831 -0.527445  0.700708
# 8    1.184150 -0.374331    ...     0.153812 -0.894390 -0.422589  0.757785
# 9    1.123099 -0.434820    ...     0.048266 -0.905812 -0.319319  0.800802
# 10   1.063471 -0.490240    ...    -0.050960 -0.905634 -0.218867  0.830962
# 11   1.005308 -0.541002    ...    -0.143409 -0.895296 -0.122192  0.849455
# 12   0.948633 -0.587476    ...    -0.228809 -0.876133 -0.030023  0.857442
# 13   0.893456 -0.629996    ...    -0.307031 -0.849373  0.057100  0.856037
# 14   0.839774 -0.668866    ...    -0.378061 -0.816142  0.138798  0.846296
# 15   0.787576 -0.704359    ...    -0.441976 -0.777463  0.214820  0.829213
# 16   0.736845 -0.736726    ...    -0.498923 -0.734265  0.285020  0.805716
# 17   0.687560 -0.766194    ...    -0.549103 -0.687387  0.349342  0.776666
# 18   0.639695 -0.792970    ...    -0.592755 -0.637583  0.407799  0.742858
# 19   0.593220 -0.817246    ...    -0.630150 -0.585529  0.460464  0.705024
# 20   0.548107 -0.839194    ...    -0.661579 -0.531830  0.507451  0.663835
# 21   0.504322 -0.858974    ...    -0.687346 -0.477024  0.548914  0.619901
# 22   0.461834 -0.876734    ...    -0.707764 -0.421590  0.585033  0.573780
# 23   0.420609 -0.892609    ...    -0.723146 -0.365949  0.616010  0.525975
# 24   0.041277 -0.972649    ...    -0.645354  0.181169  0.683405 -0.009053
# 25   0.012743 -0.973428    ...    -0.622759  0.220741  0.670711 -0.052304
# 26  -0.014919 -0.973396    ...    -0.598569  0.258260  0.655819 -0.094015
# 27  -0.041735 -0.972602    ...    -0.572971  0.293700  0.638920 -0.134106
# 28  -0.067729 -0.971092    ...    -0.546146  0.327050  0.620199 -0.172512
# 29  -0.092924 -0.968907    ...    -0.518261  0.358305  0.599832 -0.209181
# ..        ...       ...    ...          ...       ...       ...       ...
# 840  0.649643  0.787554    ...     0.584105 -0.648263 -0.395992  0.750324
# 841  0.697805  0.760228    ...     0.539102 -0.697511 -0.336306  0.783195
# 842  0.747392  0.730168    ...     0.487519 -0.743681 -0.270747  0.811146
# 843  0.798429  0.697163    ...     0.429122 -0.786001 -0.199315  0.833368
# 844  0.850938  0.660982    ...     0.363720 -0.823614 -0.122085  0.848986
# 845  0.904934  0.621368    ...     0.291182 -0.855573 -0.039221  0.857059
# 846  0.960426  0.578043    ...     0.211446 -0.880833  0.049000  0.856579
# 847  1.017415  0.530697    ...     0.124549 -0.898246  0.142166  0.846477
# 848  1.075888  0.478987    ...     0.030647 -0.906562  0.239703  0.825628
# 849  1.135819  0.422537    ...    -0.069953 -0.904423  0.340836  0.792865
# 850  1.323768  0.220290    ...    -0.405690 -0.820211  0.654200  0.611149
# 851  1.388779  0.140160    ...    -0.525397 -0.760772  0.756439  0.518936
# 852  1.454680  0.052636    ...    -0.646274 -0.682816  0.853734  0.409244
# 853  1.521198 -0.043020    ...    -0.765902 -0.584679  0.942970  0.281403
# 854  1.587961 -0.147640    ...    -0.881177 -0.464831  1.020355  0.135135
# 855  1.654474 -0.262168    ...    -0.988145 -0.322022  1.081302 -0.029256
# 856  1.720068 -0.387668    ...    -1.081822 -0.155476  1.120314 -0.210626
# 857  1.783839 -0.525352    ...    -1.155966  0.034811  1.130855 -0.406631
# 858  1.844562 -0.676587    ...    -1.202830  0.247645  1.105258 -0.613235
# 859  1.900558 -0.842920    ...    -1.212885  0.480006  1.034680 -0.824031
# 860  1.949501 -1.026085    ...    -1.174552  0.726135  0.909182 -1.029300
# 861  1.988120 -1.227996    ...    -1.074024  0.976195  0.718089 -1.214737
# 862  2.011729 -1.450700    ...    -0.895317  1.214296  0.450854 -1.359712
# 863  2.013457 -1.696237    ...    -0.620944  1.415600  0.098975 -1.434996
# 864  1.982928 -1.966306    ...    -0.233978  1.542117 -0.340046 -1.399960
# 865  1.903887 -2.261445    ...     0.276687  1.536813 -0.854612 -1.199762
# 866  1.749615 -2.579053    ...     0.903645  1.316197 -1.402403 -0.764669
# 867  1.473307 -2.908285    ...     1.590478  0.764580 -1.875641 -0.019171
# 868  0.985396 -3.215447    ...     2.156289 -0.252931 -2.027404  1.071476
# 869  0.090462 -3.394620    ...     2.101804 -1.774079 -1.321456  2.310314
#
#            45        46        47        48        49        50
# 0   -1.196528  0.809557  1.475239 -0.275434 -1.557242 -0.270989
# 1   -0.749836  1.135983  1.142707 -0.725046 -1.381581  0.245050
# 2    1.046558  0.159074 -0.986545 -0.457007  0.839064  0.702076
# 3    1.010861  0.003851 -0.998880 -0.303953  0.898240  0.565347
# 4    0.957764 -0.138076 -0.989020 -0.157519  0.932508  0.427675
# 5    0.891201 -0.265764 -0.960760 -0.019943  0.945093  0.292430
# 6    0.814546 -0.378849 -0.917498  0.107283  0.939057  0.162148
# 7    0.730661 -0.477385 -0.862246  0.223241  0.917246  0.038686
# 8    0.641965 -0.561731 -0.797645  0.327454  0.882264 -0.076643
# 9    0.550483 -0.632455 -0.725994  0.419785  0.836467 -0.182962
# 10   0.457901 -0.690267 -0.649283  0.500347  0.781964 -0.279738
# 11   0.365609 -0.735967 -0.569217  0.569440  0.720631 -0.366714
# 12   0.274745 -0.770406 -0.487254  0.627504  0.654121 -0.443842
# 13   0.186230 -0.794461 -0.404629  0.675069  0.583887 -0.511243
# 14   0.100797 -0.809005 -0.322380  0.712734  0.511193 -0.569162
# 15   0.019023 -0.814899 -0.241374  0.741135  0.437134 -0.617939
# 16  -0.058652 -0.812979 -0.162328  0.760929  0.362654 -0.657981
# 17  -0.131899 -0.804046 -0.085825  0.772778  0.288559 -0.689745
# 18  -0.200488 -0.788862 -0.012337  0.777341  0.215533 -0.713720
# 19  -0.264269 -0.768149  0.057765  0.775261  0.144153 -0.730411
# 20  -0.323162 -0.742583  0.124195  0.767163  0.074896 -0.740335
# 21  -0.377141 -0.712798  0.186742  0.753648  0.008157 -0.744006
# 22  -0.426229 -0.679384  0.245255  0.735288 -0.055746 -0.741932
# 23  -0.470487 -0.642886  0.299642  0.712628 -0.116558 -0.734612
# 24  -0.677997 -0.156038  0.633179  0.305246 -0.554712 -0.431656
# 25  -0.676011 -0.111817  0.642018  0.262700 -0.573854 -0.393225
# 26  -0.671355 -0.068497  0.647874  0.220335 -0.589879 -0.354213
# 27  -0.664208 -0.026211  0.650902  0.178328 -0.602903 -0.314838
# 28  -0.654746  0.014926  0.651255  0.136840 -0.613046 -0.275297
# 29  -0.643141  0.054813  0.649085  0.096017 -0.620429 -0.235772
# ..        ...       ...       ...       ...       ...       ...
# 840  0.186461 -0.792537  0.027519  0.776955 -0.230769 -0.709301
# 841  0.116878 -0.806468  0.101675  0.770914 -0.304071 -0.683730
# 842  0.042678 -0.813991  0.178755  0.757449 -0.378308 -0.650265
# 843 -0.035890 -0.814336  0.258266  0.735900 -0.452771 -0.608422
# 844 -0.118474 -0.806693  0.339597  0.705606 -0.526626 -0.557756
# 845 -0.204608 -0.790222  0.422003  0.665911 -0.598899 -0.497868
# 846 -0.293684 -0.764057  0.504581  0.616186 -0.668461 -0.428438
# 847 -0.384931 -0.727321  0.586255  0.555845 -0.734009 -0.349244
# 848 -0.477386 -0.679144  0.665744  0.484372 -0.794051 -0.260198
# 849 -0.569862 -0.618682  0.741542  0.401355 -0.846886 -0.161386
# 850 -0.831353 -0.356286  0.927685  0.081444 -0.941728  0.189029
# 851 -0.906140 -0.240124  0.968056 -0.048051 -0.944093  0.320529
# 852 -0.970169 -0.109395  0.992743 -0.187636 -0.927209  0.456520
# 853 -1.019955  0.035429  0.998264 -0.335676 -0.887976  0.594306
# 854 -1.051435  0.193259  0.980743 -0.489752 -0.823143  0.730315
# 855 -1.059921  0.362171  0.935937 -0.646438 -0.729420  0.859903
# 856 -1.040066  0.539117  0.859309 -0.801022 -0.603652  0.977123
# 857 -0.985873  0.719551  0.746174 -0.947162 -0.443099  1.074457
# 858 -0.890780  0.896934  0.591973 -1.076466 -0.245877  1.142532
# 859 -0.747874  1.062101  0.392740 -1.177997 -0.011637  1.169845
# 860 -0.550351  1.202443  0.145901 -1.237705  0.257388  1.142550
# 861 -0.292390  1.300897 -0.148418 -1.237863  0.554780  1.044455
# 862  0.029225  1.334753 -0.485204 -1.156643  0.867478  0.857501
# 863  0.412164  1.274421 -0.850974 -0.968222  1.172031  0.563299
# 864  0.843215  1.082642 -1.217822 -0.644298  1.428926  0.146919
# 865  1.288568  0.715522 -1.533598 -0.159120  1.574237 -0.394550
# 866  1.675987  0.129261 -1.705905  0.496899  1.508281 -1.033167
# 867  1.862129 -0.696326 -1.577598  1.282268  1.084184 -1.668836
# 868  1.575476 -1.684065 -0.898434  2.014948  0.115603 -2.038635
# 869  0.344608 -2.427001  0.648014  2.140303 -1.495499 -1.527981
#
# [870 rows x 51 columns]

# %%
# plot some H values
plt.plot(y,H[0,:], label='H0')
plt.plot(y,H[1,:], label='H1')
plt.plot(y,H[2,:], label='H2')
plt.plot(y,H[5,:], label='H5')
plt.legend()
plt.show()

# %%
for i in range(1,H.shape[0]):
    print H[i,:].mean()
    plt.plot(i,H[i,:].mean(), 'ob')
    
plt.plot([0,K], [0,0], '-k')
plt.ylim([-1,1])
plt.show()
# Out:
# -0.123396922849
# -0.0918244953649
# 0.0105902238073
# -0.0134725035499
# 0.0100826639539
# -0.00351603344329
# -0.00176354832658
# 0.0187354575959
# -0.00356102156691
# -0.0164931468512
# -0.000801503192751
# 0.00516120777331
# 0.0107739813458
# 0.00637623680906
# -0.0204417641213
# -0.0137459575839
# 0.0258577510236
# 0.0163777149443
# -0.0257960591722
# -0.0156382736632
# 0.021114153965
# 0.0133258595224
# -0.0137370458529
# -0.0108412475655
# 0.00577017656683
# 0.00891973439634
# 0.00107669493035
# -0.00770447670947
# -0.00575009876031
# 0.00696676801762
# 0.00787232321809
# -0.00634170104033
# -0.00761397222186
# 0.00550916704022
# 0.00550319074353
# -0.00429637293474
# -0.00223234349084
# 0.00270691799048
# -0.00150137669945
# -0.000895773633797
# 0.00510544104268
# -0.00088650548834
# -0.00815036642333
# 0.00235929455555
# 0.0103847796429
# -0.00327142831759
# -0.0117191648657
# 0.00344518803163
# 0.0121910050064
# -0.00280077279667

# %% [markdown]
# This shows that there is some bias in H, in the first few monomials... Compare it with the reference distribution below

# %% [markdown]
# ## Fit Anamaorphosis coefficients

# %%
PCI, g=gslib.nonlinear.fit_PCI(z,y,H)

print PCI
# Out:
# [  2.62749712e+00  -3.02564692e+00   2.36796762e+00  -1.23939884e+00
#    2.88091253e-01   2.40890994e-01  -3.32376700e-01   1.44129775e-01
#    5.86288005e-02  -1.13491827e-01   6.05986615e-02  -1.97529858e-04
#   -3.96523954e-02   5.71951532e-02  -2.46985902e-02  -4.45952121e-02
#    6.72321531e-02  -2.70095408e-03  -6.79029717e-02   4.76444179e-02
#    3.61007953e-02  -6.87370384e-02   7.73466703e-03   6.15940496e-02
#   -4.47454988e-02  -3.35841018e-02   6.36122500e-02  -2.89901102e-03
#   -6.15218286e-02   3.58376218e-02   4.22967488e-02  -5.67985801e-02
#   -1.34578071e-02   6.20795825e-02  -1.66109581e-02  -5.23530368e-02
#    4.07839027e-02   3.14540802e-02  -5.44072013e-02  -4.86911322e-03
#    5.56725209e-02  -2.16786614e-02  -4.53540689e-02   4.33161605e-02
#    2.61536794e-02  -5.66888385e-02  -1.88127050e-03   6.02205581e-02
#   -2.33502631e-02  -5.40368489e-02   4.57956234e-02]

# %% [markdown]
# ### Validate PCI
#
# There are two basic validations:
#
#  - The variance calculated from PCI may be close to the experimental variance (declustered)
#  - The error of the z' fitted with hermite polynomial expansion may be close to z

# %%
# test variance
print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(PCI)
print 'Variance experimental:             ', z.var()
# Out:
# Variance from PCI:                  16.6694648703
# Variance experimental:              15.2437634682

# %%
# test the fiiting error with polynomial expansion
ze = gslib.nonlinear.expand_anamor(PCI,H,r=1) # make sure that r == 1 for point support

fit_error = z-ze

bias = fit_error[fit_error<4].mean()

#print some comparisons
print 'Mean z', z.mean()
print 'Mean ze', ze.mean()
print 'Mean er', fit_error.mean()
print 'Var z', z.var()
print 'Var ze', ze.var()
print 'Var er', fit_error.var()
print 'Bias', bias


# scaterplots of true / estimate
plt.plot(z,ze, '+')
plt.show()

# error by y
plt.plot(y,fit_error)
plt.show()

# plot histogram of errors
pd.DataFrame({'fit_error': fit_error}).hist(bins=20)
plt.show()
# Out:
# Mean z 2.62749712013
# Mean ze 2.76257783615
# Mean er -0.135080716022
# Var z 15.2437634682
# Var ze 14.1909788588
# Var er 0.198431684363
# Bias -0.145648219355

# %%
# also plot anamorphosis function 
plt.plot(y,ze,label='Z from anamorphosis')
plt.step(y,z, label='raw')
plt.plot(transout,transin, label='original data')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#plt.plot(rz, norm.cdf(ry))
plt.plot(z,norm.cdf(y), label='experimental')
plt.plot(ze+bias, norm.cdf(y), label='fit')
plt.plot(transin,norm.cdf(transout), label='original data')
#plt.xlim(xmin=0.05)
plt.axis([0.05,10.0, 0,1])
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Using the function to transform arbitrary y values
#
# As result of some nonlinear and simulation application you may have arbitrary gaussian (Y) values you want to convert to raw (Z) values. This is partially implemented and only valid for some practical intervals.
#
# To do this is necessary to identify four set of control points:
#
#  - [yamin,zamin] admissible minimum value
#  - [ypmin,zpmin] practical minimum value
#  - [ypmax,zpmax] practical minimum value
#  - [yamax,zamin] admissible minimum value

# %%
zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax = gslib.nonlinear.ctrpoints(z,y,ze)
print zamin,yamin,zamax,yamax
print zpmin,ypmin,zpmax,ypmax
# Out:
# 0.0599999986589 -2.4686062336 42.8688392639 2.79349303246
# 0.161257877946 -1.22701394558 42.8688392639 2.79349303246

# %%
# also plot anamorphosis function 
plt.plot(y,ze,'.', label='Z from anamorphosis')
plt.plot(y,z, '+', label='raw')
plt.plot(yamin,zamin, 'ok', label='Admissible control point')
plt.plot(yamax,zamax, 'ok')
plt.plot(ypmin,zpmin, '+r', label='Practical control point')
plt.plot(ypmax,zpmax, '+r')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#test using different Y data to fit a new Z (not in the input)
yyy=np.linspace(-5,5,4000)

ZZZ=gslib.nonlinear.Y2Z(yyy,PCI,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax, r=1)

plt.plot(yyy,ZZZ, label = 'z from y in [-5, 5]')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %%
from scipy.stats import norm
plt.plot(transin,norm.pdf(transout), label='original data')
plt.plot(z, g)
plt.plot(ZZZ, norm.pdf(yyy))
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.show()

# %%
#test using different Z data to fit a new Y 
zzz=np.linspace(z.min()-1,z.max()+3,1000)

YYY=gslib.nonlinear.Z2Y_linear(zzz,ze,y,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax)

plt.plot(YYY,zzz, '.',linewidth=2.0, label = 'Y from arbitrary z')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Change of support and information effect
#
# ## Support effect
#
# To account for support effect you need to know:
#
# - point-support variance:  $Var(Zx) = γ(\infty)$
# - block-support variance: $ Var(Zv) = \gamma(\infty) − \gamma(v,v) $
#
# ## Information effect
#
# To account for information effect, in addition to the point variance and block variance, you need to know:
#
# - estimated grade variance: $ Var(Zv^*) = Var(Zv) -  \sigma^2_K - 2\mu$
# - true grade–estimated grade covariance: $Cov(Zv,Zv^*) = Var(Zv) - \sigma^2_K - \mu$
#
# Note that the information effect has two components. The smoothing due to kriging, represented by the estimated grade variance and some degree of conditional bias represented by the true grade–estimated grade covariance. Note that the amount of conditional bias can be represented as the slope of regression: $p = Cov(Zv,Zv^*) / (Cov(Zv,Zv^*)  - \mu)$

# %% [markdown]
# ## Calculating the support effect

# %%
# first we define the parameters for block covariance calculation
xsize = 5
ysize = 5
zsize = 5
nx, ny, nz = (5, 5, 5) # number of discretization points 
dx = np.linspace(0 + xsize/(2*nx), xsize-xsize/(2*nx), nx)
dy = np.linspace(0 + ysize/(2*ny), ysize-ysize/(2*ny), ny)
dz = np.linspace(0 + zsize/(2*nz), ysize-ysize/(2*nz), nz)
xv, yv, zv = np.meshgrid(dx, dy, dz)
xdb = xv.ravel() 
ydb = yv.ravel() 
zdb = zv.ravel() 

parameters_blk = { 
                'xdb'  :  xdb,       # X coordinates of discretazation points
                'ydb'  :  ydb,       # Y coordinates of discretazation points
                'zdb'  :  zdb,       # Z coordinates of discretazation points
                'it'   :  [1, 1],    # two structures: 1 spherical, 2 exponential 
                'c0'   :  [6],    # nugget,  
                'cc'   :  [10, 10],# variance of each structure 
                'aa'   :  [30, 60],  # parameter a (or range) mayor direction 
                'aa1'  :  [30, 60],  # parameter a (or range) semimayor direction 
                'aa2'  :  [30, 60],   # parameter a (or range) minor direction
                'ang1'   : [0, 0],   # Rotation angles per structure  
                'ang2'   : [0, 0],              
                'ang3'   : [0, 0]}       
      


unbias, blk_var=gslib.__block_covariance.block_covariance(**parameters_blk)

print 'var(Zx)=', blk_var
print 'unbias:', unbias
print 'f:', blk_var/unbias
# Out:
# var(Zx)= 16.979510753
# unbias: 26.0
# f: 0.653058105883

# %%
# now we can calculate r
r = gslib.nonlinear.get_r (Var_Zv=blk_var,PCI= PCI)
print r
# Out:
# 0.968972867344

# %%
# see the impact in the CDF (this time we plot z from anamorphosis)
yi=np.linspace(-3.5,3.5,4000)
H_yi = gslib.nonlinear.recurrentH(y=yi, K=K)
zp= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=1) 
zr= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=r) 

plt.plot(y,z,'k', label = 'experimental')
plt.plot(yi,zp, label = 'point')
plt.plot(yi,zr, label = 'block')

plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Calculating information effect parameters

# %% [markdown]
# Here we assume some arbitrary numbers. In practice you may do kriging in a panel with dummy future data, for example, blast holes.
#
# $ \sigma^2_K = 2 $
#
# and
#
# $ \mu = 0.5 $
#
# Then
#
# $ Var(Zv^*) = Var(Zv) -  \sigma^2_K - 2\mu$
# $ = Var(Zv) -  2 - 1 $
#
# $Cov(Zv,Zv^*) = Var(Zv) - \sigma^2_K - \mu$
# $ = Var(Zv) - 2 - 0.5$

# %%
blk_e_var= blk_var - 2. -2*0.5
blk_te_covar= blk_var - 2. -0.5
print 'Var(Zv*)=   ', blk_e_var
print 'Cov(Zv,Zv*)=', blk_te_covar
# Out:
# Var(Zv*)=    13.979510753
# Cov(Zv,Zv*)= 14.479510753

# %%
# now we can calculate s and ro
s = gslib.nonlinear.get_r (Var_Zv=blk_e_var,PCI= PCI)
ro = gslib.nonlinear.get_ro(Covar_ZvZv=blk_te_covar, PCI= PCI, r=r, s=s)
print 'r   = ', r
print 's   = ', s
print 'ro  = ', ro
print 's*ro= ', s*ro
# Out:
# r   =  0.968972867344
# s   =  0.912562221289
# ro  =  0.963057568557
# s*ro=  0.878849953991

# %%
# see the impact in the CDF (this time we plot z from anamorphosis)
zs= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=s*r) 

plt.plot(y,z,'k', label = 'experimental')
plt.plot(yi,zp, label = 'point')
plt.plot(yi,zr, label = 'block')
plt.plot(yi,zs, label = 'block*') # verify this

plt.legend(loc=2)
plt.show()
