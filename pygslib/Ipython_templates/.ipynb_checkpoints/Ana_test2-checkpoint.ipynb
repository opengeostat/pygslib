# %% [markdown]
# ## Testing nonlinear

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as plt
import pygslib as gslib
# %matplotlib inline
from scipy.stats import norm

# %% [markdown]
# ## Get some data ready for work

# %%
# using anamor transformation table directly
ttable= pd.read_csv('anamor_dec.csv')
z=ttable.z.values
y=ttable.y.values

# %% [markdown]
# ## Get transformation table

# %%
rz,ry, error = gslib.__dist_transf.anatbl(z,np.ones(z.shape[0]),despike=1)
print 'there was any error?: ', error!=0


pd.DataFrame({'z':z,'y':y, 'rz':rz, 'ry':ry }).to_csv('test.csv')

print pd.DataFrame({'z':z,'y':y, 'rz':rz, 'ry':ry }).head()
#dis is not right
# Out:
# there was any error?:  False
#          ry        rz         y         z
# 0 -3.104975  0.060035 -1.217341  0.060000
# 1 -2.893817  0.061663 -1.203999  0.061587
# 2 -2.764052  0.063560 -1.199999  0.063543
# 3 -2.668821  0.065607 -1.195999  0.065578
# 4 -2.592983  0.067730 -1.191999  0.067689

# %%
# plot experimental anamorphosis function 
plt.step(y,z, label='raw or experimental')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Experimental Gaussian anamorphosis')
#plt.yscale ('log')
#plt.xscale ('log')
#plt.legend(loc=2)
plt.show()
pd.DataFrame({'y':y}).hist(bins=50)
plt.show()
pd.DataFrame({'ry':ry}).hist(bins=50)
plt.show()

# %% [markdown]
# here we have the first problem. The anamorphosis expect gaussian but declustered values are not gaussian. In addition the mean and variance of Y are not zero and one.

# %% [markdown]
# ## Test anamorphosis

# %%
K=50
H=gslib.nonlinear.recurrentH(y=y, K=K)
rH=gslib.nonlinear.recurrentH(y=ry, K=K)
# some test plot, example lack of correlation
plt.scatter(H[1,:], H[2,:])
plt.show()
plt.scatter(H[1,:], H[3,:])
plt.show()
# Out:
# /home/adrian/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
# plot some H values
plt.plot(y,H[0,:], label='H0')
plt.plot(y,H[1,:], label='H1')
plt.plot(y,H[2,:], label='H2')
plt.plot(y,H[15,:], label='H15')
plt.legend()
plt.show()

# %%
for i in range(H.shape[0]):
    print H[i,:].mean()
    plt.plot(i,H[i,:].mean(), 'ob')
    
plt.plot([0,50], [0,0], '-k')
plt.ylim([-1,1])
plt.show()
# Out:
# 1.0
# -0.889981874512
# 0.892419792926
# -0.800037919061
# 0.189887760988
# 0.430783859626
# -0.482890831657
# 0.143132746878
# 0.187901076811
# -0.329750146458
# 0.168969583077
# 0.196074353985
# -0.32879273847
# 0.0318993520134
# 0.277342671887
# -0.188856762471
# -0.11290170222
# 0.217154184159
# -0.0560785974146
# -0.139130216702
# 0.160388619453
# 0.0124035435394
# -0.179337433987
# 0.105754962253
# 0.128713160538
# -0.177748282942
# -0.0422055704712
# 0.190635952887
# -0.0449787619312
# -0.151910063141
# 0.10664244917
# 0.081201750087
# -0.129915194567
# -0.00172358969584
# 0.114734840054
# -0.0663531220552
# -0.0704291953731
# 0.109752229466
# 0.0112056025179
# -0.12328528011
# 0.0481080013151
# 0.109009849977
# -0.0952741480065
# -0.0741636922516
# 0.12249960197
# 0.0286410138047
# -0.126982712472
# 0.0173916241371
# 0.110425077241
# -0.0553566519917
# -0.0778740523407

# %% [markdown]
# This shows that there is some bias in H, in the first few monomials... Compare it with the reference distribution below

# %%
for i in range(rH.shape[0]):
    print rH[i,:].mean()
    plt.plot(i,rH[i,:].mean(), 'ob')
    
plt.plot([0,50], [0,0], '-k')
plt.ylim([-1,1])
plt.show()
# Out:
# 1.0
# 0.0
# -0.00811912322076
# 0.0
# -0.0189374741238
# 0.0
# -0.0110689990296
# 1.35341473478e-17
# 0.00979632593087
# -1.35341473478e-17
# 0.00243805723448
# 0.0
# -0.00848591810778
# 0.0
# 0.00601479179845
# 1.35341473478e-17
# 0.000161031023279
# 6.76707367391e-18
# -0.00502173220632
# 6.76707367391e-18
# 0.00622482210882
# 6.76707367391e-18
# -0.00408468315615
# 0.0
# 0.000350526163141
# 6.76707367391e-18
# 0.00306295843559
# 0.0
# -0.00487766853734
# 0.0
# 0.00471267811366
# 0.0
# -0.00294760029487
# 3.38353683695e-18
# 0.000391295187118
# 3.38353683695e-18
# 0.00207202190498
# 0.0
# -0.00375164996402
# -1.01506105109e-17
# 0.00429114552509
# 0.0
# -0.00368616059017
# -3.38353683695e-18
# 0.00221237639534
# 6.76707367391e-18
# -0.000306166437835
# 6.76707367391e-18
# -0.00156261075405
# -3.38353683695e-18
# 0.00299668972482

# %% [markdown]
# ## Fit Anamaorphosis coefficients

# %%
rPCI=gslib.nonlinear.fit_PCI(rz,ry,rH)

PCI, g =gslib.nonlinear.fit_PCI(z,y,H)

# %%
# get PCI froma anamor.exe for some test
ttt=pd.read_csv('APCI.csv')
anaPCI=ttt.APCI.values

print anaPCI.shape
print PCI.shape

pd.DataFrame({'mypcy': PCI[:-1], 'anaPCI':anaPCI })
# Out:
# (50,)
# (51,)
#       anaPCI     mypcy
# 0   2.528120  9.673872
# 1  -3.202128 -3.187704
# 2   2.687988  2.653570
# 3  -1.655096 -1.617136
# 4   0.660798  0.634388
# 5   0.067000  0.079423
# 6  -0.408571 -0.396881
# 7   0.355105  0.324935
# 8  -0.084300 -0.068090
# 9  -0.156556 -0.143018
# 10  0.218571  0.195030
# 11 -0.094100 -0.083977
# 12 -0.103108 -0.093197
# 13  0.188965  0.167299
# 14 -0.064900 -0.054297
# 15 -0.135290 -0.118314
# 16  0.166391  0.141812
# 17  0.014500  0.012024
# 18 -0.170791 -0.144923
# 19  0.096400  0.084089
# 20  0.102325  0.086629
# 21 -0.154007 -0.133830
# 22 -0.004900 -0.005114
# 23  0.149233  0.131023
# 24 -0.081500 -0.066449
# 25 -0.096600 -0.088758
# 26  0.132211  0.108442
# 27  0.021300  0.027827
# 28 -0.139337 -0.115387
# 29  0.052000  0.031904
# 30  0.108740  0.092421
# 31 -0.104628 -0.076290
# 32 -0.054300 -0.050476
# 33  0.127270  0.098423
# 34 -0.007650  0.001926
# 35 -0.119210 -0.097925
# 36  0.062300  0.042515
# 37  0.086400  0.079084
# 38 -0.099300 -0.075484
# 39 -0.038500 -0.048669
# 40  0.113538  0.093433
# 41 -0.013600  0.013977
# 42 -0.104816 -0.096237
# 43  0.060000  0.018604
# 44  0.077100  0.086307
# 45 -0.093500 -0.044449
# 46 -0.036700 -0.067534
# 47  0.109727  0.060990
# 48 -0.008700  0.044300
# 49 -0.107901 -0.067613

# %%
#print PCI
plt.plot(np.arange(PCI.shape[0])+1, PCI)
plt.xlabel('K')
plt.ylabel('Y')
plt.show()

#print PCI


print PCI
# Out:
# [  9.67387223e+00  -3.18770407e+00   2.65357022e+00  -1.61713644e+00
#    6.34388452e-01   7.94225922e-02  -3.96880506e-01   3.24935013e-01
#   -6.80895757e-02  -1.43018092e-01   1.95029560e-01  -8.39770283e-02
#   -9.31973045e-02   1.67299262e-01  -5.42968036e-02  -1.18314292e-01
#    1.41812482e-01   1.20240946e-02  -1.44922823e-01   8.40886112e-02
#    8.66292800e-02  -1.33830274e-01  -5.11422698e-03   1.31023062e-01
#   -6.64494323e-02  -8.87584013e-02   1.08441534e-01   2.78273426e-02
#   -1.15387442e-01   3.19038305e-02   9.24213147e-02  -7.62901019e-02
#   -5.04758688e-02   9.84232721e-02   1.92599752e-03  -9.79253570e-02
#    4.25152582e-02   7.90840135e-02  -7.54838396e-02  -4.86688064e-02
#    9.34329489e-02   1.39774453e-02  -9.62370216e-02   1.86043047e-02
#    8.63066347e-02  -4.44485719e-02  -6.75339725e-02   6.09899497e-02
#    4.43003526e-02  -6.76126492e-02  -2.06854183e-02]

# %% [markdown]
# ### Validate PCI
#
# There are two basic validations:
#
#  - The variance calculated from PCI may be close to the experimental variance (declustered)
#  - The error of the z' fitted with hermite polynomial expansion may be close to z

# %%
# test variance
print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(PCI)
print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(rPCI)
print 'Variance experimental:             ', np.var(z)
# Out:
# Variance from PCI:                  20.8392910569
# Variance from PCI:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-aaa92de83327> in <module>()
#       1 # test variance
#       2 print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(PCI)
# ----> 3 print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(rPCI)
#       4 print 'Variance experimental:             ', np.var(z)
#
# TypeError: Argument 'PCI' has incorrect type (expected numpy.ndarray, got tuple)

# %%
# test the fiiting error with polynomial expansion
ze = gslib.nonlinear.expand_anamor(PCI,H,r=1) # make sure that r == 1 for point support

zee = gslib.nonlinear.expand_anamor(anaPCI,H,r=1)

fit_error = z-zee

#print some comparisons
print 'Mean z', z.mean()
print 'Mean ze', zee.mean()
print 'Var z', z.var()
print 'Var ze', zee.var()

# scaterplots of true / estimate
plt.plot(z,zee, '+')
plt.show()

# error by y
plt.plot(y,fit_error)
plt.show()

# plot histogram of errors
pd.DataFrame({'fit_error': fit_error}).hist(bins=K)
plt.show()
# Out:
# Mean z 9.67387222863
# Mean ze 9.67389735866
# Var z 173.190227028
# Var ze 173.192471988

# %%
# also plot anamorphosis function 
plt.plot(y,zee,label='Z from anamorphosis')
plt.plot(y,z, label='raw')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# <p>
# <div class="alert alert-danger">
#  ** Warning: ** There is bias if you use declustering, we are investigating this.
#  See the non declusterd example "Anamor not declustered"
# </div>

# %% [markdown]
# # Using the function to transform arbitrary y values
#
# As result of some nonlinear and simulation application you may have arbitrary gaussian (Y) values you want to convert to raw (Z) values. This is partially implemented and only valid for some practical intervals.
#
# To do this is necessary to identify four set of control points:
#
#  - [yamin,zamin] admissible minimum value
#  - [ypmin,zpmin] practical minimum value
#  - [ypmax,zpmax] practical minimum value
#  - [yamax,zamin] admissible minimum value

# %%
zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax = gslib.nonlinear.ctrpoints(z,y,ze)
print zamin,yamin,zamax,yamax
print zpmin,ypmin,zpmax,ypmax
# Out:
# 0.0600345209241 -2.27403211594 58.3200035095 2.45256710052
# 0.31009671092 -0.77213716507 58.3200035095 2.45256710052

# %%
# also plot anamorphosis function 
plt.plot(y,ze,'.', label='Z from anamorphosis')
plt.plot(y,z, '+', label='raw')
plt.plot(yamin,zamin, 'ok', label='Admissible control point')
plt.plot(yamax,zamax, 'ok')
plt.plot(ypmin,zpmin, '+r', label='Practical control point')
plt.plot(ypmax,zpmax, '+r')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#test using different Y data to fit a new Z (not in the input)
yyy=np.linspace(-5,5,4000)

ZZZ=gslib.nonlinear.Y2Z(yyy,PCI,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax, r=1)

plt.plot(yyy,ZZZ, label = 'z from y in [-5, 5]')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %%
#test using different Z data to fit a new Y 
zzz=np.linspace(z.min()-1,z.max()+3,1000)

YYY=gslib.nonlinear.Z2Y_linear(zzz,ze,y,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax)

plt.plot(YYY,zzz, '.',linewidth=2.0, label = 'Y from arbitrary z')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Change of support and information effect
#
# ## Support effect
#
# To account for support effect you need to know:
#
# - point-support variance:  $Var(Zx) = γ(\infty)$
# - block-support variance: $ Var(Zv) = \gamma(\infty) − \gamma(v,v) $
#
# ## Information effect
#
# To account for information effect, in addition to the point variance and block variance, you need to know:
#
# - estimated grade variance: $ Var(Zv^*) = Var(Zv) -  \sigma^2_K - 2\mu$
# - true grade–estimated grade covariance: $Cov(Zv,Zv^*) = Var(Zv) - \sigma^2_K - \mu$
#
# Note that the information effect has two components. The smoothing due to kriging, represented by the estimated grade variance and some degree of conditional bias represented by the true grade–estimated grade covariance. Note that the amount of conditional bias can be represented as the slope of regression: $p = Cov(Zv,Zv^*) / (Cov(Zv,Zv^*)  - \mu)$

# %% [markdown]
# ## Calculating the support effect

# %%
# first we define the parameters for block covariance calculation
xsize = 5
ysize = 5
zsize = 5
nx, ny, nz = (5, 5, 5) # number of discretization points 
dx = np.linspace(0 + xsize/(2*nx), xsize-xsize/(2*nx), nx)
dy = np.linspace(0 + ysize/(2*ny), ysize-ysize/(2*ny), ny)
dz = np.linspace(0 + zsize/(2*nz), ysize-ysize/(2*nz), nz)
xv, yv, zv = np.meshgrid(dx, dy, dz)
xdb = xv.ravel() 
ydb = yv.ravel() 
zdb = zv.ravel() 

parameters_blk = { 
                'xdb'  :  xdb,       # X coordinates of discretazation points
                'ydb'  :  ydb,       # Y coordinates of discretazation points
                'zdb'  :  zdb,       # Z coordinates of discretazation points
                'it'   :  [1, 1],    # two structures: 1 spherical, 2 exponential 
                'c0'   :  [6],    # nugget,  
                'cc'   :  [10, 10],# variance of each structure 
                'aa'   :  [30, 60],  # parameter a (or range) mayor direction 
                'aa1'  :  [30, 60],  # parameter a (or range) semimayor direction 
                'aa2'  :  [30, 60],   # parameter a (or range) minor direction
                'ang1'   : [0, 0],   # Rotation angles per structure  
                'ang2'   : [0, 0],              
                'ang3'   : [0, 0]}       
      


unbias, blk_var=gslib.__block_covariance.block_covariance(**parameters_blk)

print 'var(Zx)=', blk_var
print 'unbias:', unbias
print 'f:', blk_var/unbias
# Out:
# var(Zx)= 16.979510753
# unbias: 26.0
# f: 0.653058105883

# %%
# now we can calculate r
r = gslib.nonlinear.get_r (Var_Zv=blk_var,PCI= PCI)
print r
# Out:
# 0.833818556982

# %%
# see the impact in the CDF (this time we plot z from anamorphosis)
yi=np.linspace(-3.5,3.5,4000)
H_yi = gslib.nonlinear.recurrentH(y=yi, K=K)
zp= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=1) 
zr= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=r) 

plt.plot(y,z,'k', label = 'experimental')
plt.plot(yi,zp, label = 'point')
plt.plot(yi,zr, label = 'block')

plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Calculating information effect parameters

# %% [markdown]
# Here we assume some arbitrary numbers. In practice you may do kriging in a panel with dummy future data, for example, blast holes.
#
# $ \sigma^2_K = 2 $
#
# and
#
# $ \mu = 0.5 $
#
# Then
#
# $ Var(Zv^*) = Var(Zv) -  \sigma^2_K - 2\mu$
# $ = Var(Zv) -  2 - 1 $
#
# $Cov(Zv,Zv^*) = Var(Zv) - \sigma^2_K - \mu$
# $ = Var(Zv) - 2 - 0.5$

# %%
blk_e_var= blk_var - 2. -2*0.5
blk_te_covar= blk_var - 2. -0.5
print 'Var(Zv*)=   ', blk_e_var
print 'Cov(Zv,Zv*)=', blk_te_covar
# Out:
# Var(Zv*)=    13.979510753
# Cov(Zv,Zv*)= 14.479510753

# %%
# now we can calculate s and ro
s = gslib.nonlinear.get_r (Var_Zv=blk_e_var,PCI= PCI)
ro = gslib.nonlinear.get_ro(Covar_ZvZv=blk_te_covar, PCI= PCI, r=r, s=s)
print 'r   = ', r
print 's   = ', s
print 'ro  = ', ro
print 's*ro= ', s*ro
# Out:
# r   =  0.833818556982
# s   =  0.783230811357
# ro  =  0.961273747303
# s*ro=  0.752899217037

# %%
# see the impact in the CDF (this time we plot z from anamorphosis)
zs= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=s*r) 

plt.plot(y,z,'k', label = 'experimental')
plt.plot(yi,zp, label = 'point')
plt.plot(yi,zr, label = 'block')
plt.plot(yi,zs, label = 'block*') # verify this

plt.legend(loc=2)
plt.show()
