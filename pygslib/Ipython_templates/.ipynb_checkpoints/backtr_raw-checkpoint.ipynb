# %% [markdown]
# Testing the back normalscore transformation
# ========

# %%
#general imports
import matplotlib.pyplot as plt   
import pygslib as gslib    
from matplotlib.patches import Ellipse
import numpy as np
import pandas as pd

#make the plots inline
# %matplotlib inline

# %% [markdown]
# Getting the data ready for work
# ---------
# If the data is in GSLIB format you can use the function `gslib.read_gslib_file(filename)` to import the data into a Pandas DataFrame.

# %%
#get the data in gslib format into a pandas Dataframe
mydata= gslib.read_gslib_file('../datasets/cluster.dat')

# %%
#view data in a 2D projection
plt.scatter(mydata['Xlocation'],mydata['Ylocation'], c=mydata['Primary'])
plt.colorbar()
plt.grid(True)
plt.show()

# %% [markdown]
# ## The nscore transformation table function

# %%
print gslib.__dist_transf.bacnscore.__doc__
# Out:
# va,error = bacnscore(vnsc,transin,transout,ltail,utail,ltpar,utpar,zmin,zmax,getrank,[overwrite_vnsc,overwrite_transin,overwrite_transout])
#
# Wrapper for ``bacnscore``.
#
# Parameters
# ----------
# vnsc : input rank-1 array('d') with bounds (nd)
# transin : input rank-1 array('d') with bounds (nt)
# transout : input rank-1 array('d') with bounds (nt)
# ltail : input int
# utail : input int
# ltpar : input float
# utpar : input float
# zmin : input float
# zmax : input float
# getrank : input int
#
# Other Parameters
# ----------------
# overwrite_vnsc : input int, optional
#     Default: 0
# overwrite_transin : input int, optional
#     Default: 0
# overwrite_transout : input int, optional
#     Default: 0
#
# Returns
# -------
# va : rank-1 array('d') with bounds (nd)
# error : int

# %% [markdown]
# ## Get the transformation table

# %%
transin,transout, error = gslib.__dist_transf.ns_ttable(mydata['Primary'],mydata['Declustering Weight'])
print 'there was any error?: ', error!=0
# Out:
# there was any error?:  False

# %% [markdown]
# ##Get the normal score transformation
#
# Note that the declustering is applied on the transformation tables

# %%
mydata['NS_Primary'] = gslib.__dist_transf.nscore(mydata['Primary'],transin,transout,getrank=False)

# %%
mydata['NS_Primary'].hist(bins=30)

# %% [markdown]
# ## Doing the back transformation

# %%
mydata['NS_Primary_BT'],error = gslib.__dist_transf.bacnscore(mydata['NS_Primary'],
                                     transin,transout,
                                     ltail=1,utail=1,ltpar=0,utpar=60,
                                     zmin=0,zmax=60,getrank=False)
print 'there was any error?: ', error!=0, error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-75dd824b8215> in <module>()
# ----> 1 mydata['NS_Primary_BT'],error = gslib.__dist_transf.bacnscore(mydata['NS_Primary'],
#       2                                      transin,transout,
#       3                                      ltail=1,utail=1,ltpar=0,utpar=60,
#       4                                      zmin=0,zmax=60,getrank=False)
#       5 print 'there was any error?: ', error!=0, error
#
# NameError: name 'gslib' is not defined

# %%
mydata[['Primary','NS_Primary_BT']].hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc180037d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc183f1d850>]], dtype=object)

# %%
mydata[['Primary','NS_Primary_BT']]
# Out:
#      Primary  NS_Primary_BT
# 0       0.06       0.060000
# 1       0.06       0.060000
# 2       0.08       0.080000
# 3       0.09       0.090001
# 4       0.09       0.090000
# 5       0.10       0.100001
# 6       0.10       0.100001
# 7       0.11       0.110000
# 8       0.11       0.110001
# 9       0.16       0.160001
# 10      0.16       0.160001
# 11      0.17       0.170000
# 12      0.18       0.180000
# 13      0.19       0.190000
# 14      0.19       0.190001
# 15      0.19       0.190000
# 16      0.22       0.220001
# 17      0.24       0.240001
# 18      0.26       0.260000
# 19      0.28       0.280001
# 20      0.28       0.280001
# 21      0.31       0.310000
# 22      0.32       0.320001
# 23      0.33       0.330001
# 24      0.34       0.340000
# 25      0.34       0.340001
# 26      0.34       0.340000
# 27      0.40       0.400001
# 28      0.45       0.450000
# 29      0.46       0.460000
# ..       ...            ...
# 110    15.77      15.770001
# 111    20.35      20.350000
# 112     5.54       5.540001
# 113     5.38       5.380000
# 114    15.77      15.770001
# 115    10.20      10.200000
# 116     9.01       9.010001
# 117     9.27       9.270000
# 118     3.56       3.560000
# 119     2.52       2.520000
# 120    18.64      18.640000
# 121     7.94       7.940000
# 122     2.28       2.280001
# 123     2.51       2.510001
# 124    19.44      19.440001
# 125     2.96       2.960000
# 126     2.97       2.970000
# 127     4.92       4.920001
# 128     5.54       5.540000
# 129     8.71       8.710000
# 130     2.74       2.740000
# 131     3.61       3.610000
# 132    58.32      58.320001
# 133    11.08      11.080000
# 134    21.08      21.080001
# 135    22.75      22.750000
# 136     9.42       9.420000
# 137     8.48       8.480001
# 138     2.82       2.820001
# 139     5.26       5.260001
#
# [140 rows x 2 columns]

# %% [markdown]
# ## Comment
#
# bacnscore call ndata times the function backtr. To get the backtransformation for a single value use this function like this

# %%
print 'The Z value of -2.5 is: ', gslib.__dist_transf.backtr(vrgs=-2.5,vr=transin,vrg=transout,zmin=0,zmax=60,ltail=1,ltpar=0,utail=1,utpar=60)
print 'The Z value of 2.5 is: ', gslib.__dist_transf.backtr(vrgs=2.5,vr=transin,vrg=transout,zmin=0,zmax=60,ltail=1,ltpar=0,utail=1,utpar=60)
# Out:
# The Z value of -2.5 is:  0.0600000346878
# The Z value of 2.5 is:  21.7561123355
