# %% [markdown]
# ## Testing nonlinear (temporal development)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as plt
import pygslib as gslib
# %matplotlib inline
from scipy.stats import norm

# %% [markdown]
# ## Get some data ready for work and build experimental transformation
#
# The only way to make it work was:
#
# - nscore [an despike] with ``gslib.nonlinear.ttable`` and get ``yt, zt, f``
# - take a regular sample on probabilities from experimental ``f.min(), f.max()``
# - convert ``p`` to ``y`` values using ``y = norm.ppf(p)``
# - back transform ``y`` to ``z`` using ``gslib.__dist_transf.backtr`` with transformation table ``yt, zt``
# - finally do gaussian anamorphosis with ``y, z``
#
# For non declustered samples the algorithm can be simplified to:
#
# - nscore [an despike] with ``gslib.nonlinear.ttable`` and get ``y, z``
# - finally do gaussian anamorphosis with ``y, z``
#
# <p>
# <div class="alert alert-danger">
#  ** Warning: ** There may be some bias if you do anamorphosis with declustered raw data.
# </div>
#
# <p>
# <div class="alert alert-info">
#  ** Info: ** By using "despikes" in the way proposed the local atoms and isolated values are well reproduced in the experimental anamorphosis.
# </div>

# %%
#get the raw data in gslib format into a pandas Dataframe
mydata= gslib.read_gslib_file('../datasets/cluster.dat')

zt,yt,f,w = gslib.nonlinear.ttable (mydata['Primary'].values, 
                                  mydata['Declustering Weight'].values,
                                  despkn=10,despks=0.01, despkm=True)

#get nice homogeneus distribution
p= np.linspace(f.min(), f.max(),yt.shape[0]*10) 

y = norm.ppf(p)

z,error = gslib.__dist_transf.backtr(y,zt,yt,
                                     ltail=1,utail=1,ltpar=zt.min(),utpar=zt.max(),
                                     zmin=zt.min(),zmax=zt.max(),getrank=False)

#mydata

# %% [markdown]
# ## Get transformation table

# %%
# we already have Z, Y

print y.mean(), y.var() # this is 0 an 1? 
print z.mean(), z.var() # this is around data mean and variance
print mydata['Primary'].mean(), mydata['Primary'].var()
#pd.DataFrame({'z':z,'y':y})
# Out:
# 0.00130891857479 0.992566065747
# 2.52237090204 21.6924238181
# 4.35042857143 45.2474818294

# %%
# plot experimental anamorphosis function 
plt.step(y,z,'.', where='mid', label='raw or experimental')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Experimental Gaussian anamorphosis')
#plt.yscale ('log')
#plt.xscale ('log')
#plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Test anamorphosis

# %%
K=50
H=gslib.nonlinear.recurrentH(y=y, K=K)
# some test plot, example lack of correlation
plt.scatter(H[1,:], H[2,:])
plt.show()
plt.scatter(H[1,:], H[3,:])
plt.show()

print H.shape, y.shape

pd.DataFrame (H.T, columns=range(H.shape[0]))
# Out:
# /home/adrian/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# (51, 15350) (15350,)
#        0         1         2          3          4          5         6   \
# 0       1  3.276432  6.883689  10.346328  10.988070   6.846397 -0.872964
# 1       1  3.243311  6.730998   9.955820  10.315697   6.057677 -1.396074
# 2       1  3.213407  6.594465   9.610720   9.730601   5.387554 -1.815024
# 3       1  3.186126  6.471016   9.302041   9.214673   4.809794 -2.155562
# 4       1  3.161028  6.358374   9.023195   8.754773   4.305636 -2.435622
# ...         ...       ...       ...       ...       ...       ...       ...
# 15320  2.716926 -1.020321 -2.255052  1.954370  1.421051 -2.517526 -0.383957
# 15321  2.720569 -1.207551 -2.177523  2.110369  1.276522 -2.614481 -0.197696
# 15322  2.711054 -1.400288 -2.083998  2.264929  1.116202 -2.703111  0.001192
# 15323  2.686736 -1.597880 -1.973075  2.416728  0.939234 -2.781662  0.212818
# 15324  2.645800 -1.799480 -1.843262  2.564203  0.744784 -2.848139  0.437158
# 15325  2.586247 -2.004012 -1.692986  2.705509  0.532062 -2.900273  0.674017
# 15326  2.505871 -2.210116 -1.520598  2.838471  0.300356 -2.935487  0.922980
# 15327  2.402251 -2.416091 -1.324385  2.960527  0.049069 -2.950855  1.183348
# 15328  2.272735 -2.619821 -1.102595  3.068664 -0.222225 -2.943061  1.454064
# 15329  2.114425 -2.818685 -0.853467  3.159337 -0.513705 -2.908350  1.733614
# 15330  1.924179 -3.009451 -0.575282  3.228381 -0.825216 -2.842479  2.019903
# 15331  1.698607 -3.188131 -0.266432  3.270905 -1.156133 -2.740670  2.310099
# 15332  1.434097 -3.349825  0.074471  3.281163 -1.505196 -2.597558  2.600434
# 15333  1.126852 -3.488505  0.448451  3.252419 -1.870284 -2.407157  2.885948
# 15334  0.772976 -3.596760  0.855946  3.176780 -2.248106 -2.162837  3.160160
# 15335  0.368616 -3.665483  1.296507  3.045022 -2.633796 -1.857343  3.414651
# 15336 -0.089811 -3.683471  1.768344  2.846405 -3.020346 -1.482877  3.638514
# 15337 -0.605224 -3.636946  2.267680  2.568492 -3.397850 -1.031293  3.817656
# 15338 -1.179273 -3.508969  2.787807  2.197029 -3.752441 -0.494487  3.933889
# 15339 -1.811337 -3.278753  3.317687  1.715934 -4.064836  0.134872  3.963768
# 15340 -2.496917 -2.920885  3.839862  1.107569 -4.308292  0.862033  3.877111
# 15341 -3.225002 -2.404568  4.327307  0.353585 -4.445745  1.687833  3.635189
# 15342 -3.973691 -1.693122  4.738587 -0.563074 -4.425806  2.604551  3.188642
# 15343 -4.702776 -0.744408  5.010340 -1.653761 -4.177201  3.588461  2.475476
# 15344 -5.340848  0.486181  5.045424 -2.914712 -3.601361  4.586163  1.420358
# 15345 -5.762258  2.035940  4.694174 -4.306806 -2.563596  5.488877 -0.061277
# 15346 -5.744628  3.906997  3.725343 -5.710791 -0.886762  6.082471 -2.043684
# 15347 -4.888522  5.987730  1.785881 -6.823409  1.634435  5.946980 -4.522805
# 15348 -2.467718  7.818809 -1.623715 -6.900152  5.118106  4.251559 -7.186514
# 15349  2.779509  7.816568 -6.923586 -4.074958  8.981504 -0.614275 -8.576577
#
# [15350 rows x 51 columns]

# %%
# plot some H values
plt.plot(y,H[0,:], label='H0')
plt.plot(y,H[1,:], label='H1')
plt.plot(y,H[2,:], label='H2')
plt.plot(y,H[5,:], label='H5')
plt.legend()
plt.show()

# %%
for i in range(1,H.shape[0]):
    print H[i,1:].mean()
    plt.plot(i,H[i,:].mean(), 'ob')
    
plt.plot([0,K], [0,0], '-k')
plt.ylim([-1,1])
plt.show()
# Out:
# -0.00152246609826
# -0.00570419428166
# -0.00543699906824
# -0.013559766304
# -0.00502576961672
# -0.00910888869058
# 0.00298453585377
# 0.00551840641291
# 0.002643600588
# 0.00297136562597
# -0.0041199320835
# -0.00522643817793
# 0.00146510503195
# 0.002389979474
# 0.0019406406623
# 0.0012463701382
# -0.00347039026152
# -0.00303423709577
# 0.00259972461758
# 0.00263781384501
# -0.000353019300892
# -0.0010192482371
# -0.00181745894951
# -0.000664426667259
# 0.00288424192309
# 0.00167410791442
# -0.00256847445401
# -0.00181578872638
# 0.00123003749354
# 0.00128892767387
# 0.000454358784745
# -0.000456793219565
# -0.00182385254631
# -0.000339531876082
# 0.00245705204775
# 0.000880333683896
# -0.00225103234151
# -0.00108729962295
# 0.00137914533555
# 0.000993738845819
# -0.000178683380834
# -0.000695724663457
# -0.000978464885498
# 0.000306242998619
# 0.0017922415669
# 7.65410822785e-05
# -0.00209684908493
# -0.00038473394506
# 0.00187562959069
# 0.000583087418183

# %% [markdown]
# ## Fit Anamaorphosis coefficients

# %%
mean = np.sum(mydata['Primary'].values*(mydata['Declustering Weight'].values/ \
       mydata['Declustering Weight'].values.sum()))
print mean

PCI, g=gslib.nonlinear.fit_PCI(z,y,H, meanz=mean)
# Out:
# 2.52812132597

# %% [markdown]
# ### Validate PCI
#
# There are two basic validations:
#
#  - The variance calculated from PCI may be close to the experimental variance (declustered)
#  - The error of the z' fitted with hermite polynomial expansion may be close to z

# %%
# test variance
print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(PCI)
print 'Variance experimental:             ', z.var(), mydata['Primary'].var()
# Out:
# Variance from PCI:                  21.3851783549
# Variance experimental:              21.6924238181 45.2474818294

# %%
# test the fiiting error with polynomial expansion
ze = gslib.nonlinear.expand_anamor(PCI,H,r=1) # make sure that r == 1 for point support

fit_error = z-ze

bias = fit_error.mean()

#print some comparisons
print 'Mean z', z.mean()
print 'Mean ze', ze.mean()
print 'Mean er', fit_error.mean()
print 'Var z', z.var()
print 'Var ze', ze.var()
print 'Var er', fit_error.var()
print 'Bias', bias


# scaterplots of true / estimate
plt.plot(z,ze, '+')
plt.show()

# error by y
plt.plot(y,fit_error)
plt.show()

# plot histogram of errors
pd.DataFrame({'fit_error': fit_error}).hist(bins=20)
plt.show()
# Out:
# Mean z 2.52237090204
# Mean ze 2.51702086652
# Mean er 0.00535003551777
# Var z 21.6924238181
# Var ze 21.0140820961
# Var er 0.548106615085
# Bias 0.00535003551777

# %%
# also plot anamorphosis function 
plt.plot(y,ze,label='Z from anamorphosis')
plt.step(y,z,where='mid', label='raw')
plt.step(yt,zt,where='mid', label='original')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#plt.plot(rz, norm.cdf(ry))
plt.step(z,norm.cdf(y), label='experimental')
plt.plot(ze, norm.cdf(y), label='fit')
#plt.xlim(xmin=0.05)
plt.axis([0.05,10.0, 0,1])
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Using the function to transform arbitrary y values
#
# As result of some nonlinear and simulation application you may have arbitrary gaussian (Y) values you want to convert to raw (Z) values. This is partially implemented and only valid for some practical intervals.
#
# To do this is necessary to identify four set of control points:
#
#  - [yamin,zamin] admissible minimum value
#  - [ypmin,zpmin] practical minimum value
#  - [ypmax,zpmax] practical minimum value
#  - [yamax,zamin] admissible minimum value

# %%
zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax = gslib.nonlinear.ctrpoints(z,y,ze)


print 'Minimum absolute value for Y  =', yamin
print 'Maximum absolute value for Y  =', yamax
print 'Minimum absolute value for Z  =', zamin
print 'Maximum absolute value for Z  =', zamax

print 'Minimum practical value for Y =', ypmin
print 'Maximum practical value for Y =', ypmax
print 'Minimum practical value for Z =', zpmin
print 'Maximum practical value for Z =', zpmax
# Out:
# Minimum absolute value for Y  = -3.27643203735
# Maximum absolute value for Y  = 3.62211728096
# Minimum absolute value for Z  = 0.0590293854475
# Maximum absolute value for Z  = 59.4489440918
# Minimum practical value for Y = -1.27374744415
# Maximum practical value for Y = 3.00726985931
# Minimum practical value for Z = 0.159522533417
# Maximum practical value for Z = 58.3857955933

# %%
# also plot anamorphosis function 
plt.plot(y,ze,'.', label='Z from anamorphosis')
plt.step(y,z, '-', label='raw')
plt.plot(yamin,zamin, 'ok', label='Admissible control point')
plt.plot(yamax,zamax, 'ok')
plt.plot(ypmin,zpmin, '+r', label='Practical control point')
plt.plot(ypmax,zpmax, '+r')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#test using different Y data to fit a new Z (not in the input)
yyy=np.linspace(-5,5,4000)

ZZZ=gslib.nonlinear.Y2Z(yyy,PCI,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax, r=1)

plt.plot(yyy,ZZZ, label = 'z from y in [-5, 5]')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %%
from scipy.stats import norm
plt.plot(z, g)
plt.plot(ZZZ, norm.pdf(yyy))
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.show()

# %%
#test using different Z data to fit a new Y 
zzz=np.linspace(z.min()-1,z.max()+3,1000)

YYY=gslib.nonlinear.Z2Y_linear(zzz,ze,y,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax)

plt.plot(YYY,zzz, '.',linewidth=2.0, label = 'Y from arbitrary z')
plt.step(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()
