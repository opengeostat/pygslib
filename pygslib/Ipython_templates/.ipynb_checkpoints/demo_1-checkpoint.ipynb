# %% [markdown]
# # All in one example
#
# In this example:
#
# - Drillhole / data preparation
#  - we import and clean drillhole database
#  - desurvey database
#  - export to vtk for visual validation
# - Block model preparation
#  - Fill blocks (entire model)
#  - Select blocks below the topo
# - Estimation
#  - Estimate distance from drillhole
#  - Estimate with ID2 Au grade in blocks (point estimation)

# %% [markdown]
# ## Drillhole and data preparation

# %%
# import required libraries
import pygslib as gslib
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
# %matplotlib inline

# %%
# import data from file
collar = pd.read_csv('../datasets/dhole_data2/collar.csv')
survey = pd.read_csv('../datasets/dhole_data2/survey.csv')
assay = pd.read_csv('../datasets/dhole_data2/assay.csv')
litho = pd.read_csv('../datasets/dhole_data2/litho.csv')

#sort all
collar.sort_values(by=['BHID'], inplace=True)
survey.sort_values(by=['BHID', 'AT'], inplace=True)
assay.sort_values(by=['BHID', 'FROM'], inplace=True)
litho.sort_values(by=['BHID', 'FROM'], inplace=True)

# %%
# test duplicates in collar
print collar.columns
print collar['BHID'].shape[0]
print collar['BHID'].unique().shape[0]
# Out:
# Index([u'Unnamed: 0', u'BHID', u'XCOLLAR', u'YCOLLAR', u'ZCOLLAR', u'AZ_UTM',
#        u'DIP', u'LENGTH_M', u'NO_DATA', u'DOUBTFUL_C'],
#       dtype='object')
# 1083
# 1083

# %%
# review columns names (you can do this in excel...)
print survey.columns
print assay.columns
print litho.columns
# Out:
# Index([u'Unnamed: 0', u'BHID', u'AT', u'AZ', u'DIP'], dtype='object')
# Index([u'Unnamed: 0', u'BHID', u'FROM', u'TO', u'AU_AVG_GT'], dtype='object')
# Index([u'Unnamed: 0', u'BHID', u'FROM', u'TO', u'LITHO_DESC'], dtype='object')

# %%
# review some row values (you can do this in excel...)
print survey.head(5)
print assay.head(5)
print litho.head(5)
# Out:
#    Unnamed: 0   BHID      AT      AZ  DIP
# 0           4     10    0.00  173.31   43
# 1           5     10   30.48  173.31   47
# 2         231  10165    0.00  182.31   90
# 3         232  10165   60.96  182.31   88
# 4         233  10165  121.92  182.31   87
#    Unnamed: 0 BHID      FROM        TO  AU_AVG_GT
# 0          23   10  27.91968  29.13888     11.314
# 1          24   10  29.13888  30.02280      2.743
# 2          25   10  30.02280  30.66288     20.571
# 3          26   10  30.66288  32.18688     51.771
# 4          27   10  32.18688  32.64408      3.600
#    Unnamed: 0   BHID   FROM     TO                    LITHO_DESC
# 0          14     10   0.00   5.48                        Casing
# 1          15     10   5.48  25.90                 Early Diorite
# 2          16     10  25.90  28.95  Felsic to Intermediate Dykes
# 3          17     10  28.95  39.92                    Shear Zone
# 4         566  10165   0.00   3.65                        Casing

# %%
# verify that datatypes are correct. We don't want BHIDs with different dtypes or Grade as 'str'  
print survey.dtypes
print assay.dtypes
print litho.dtypes
# Out:
# Unnamed: 0      int64
# BHID           object
# AT            float64
# AZ            float64
# DIP           float64
# dtype: object
# Unnamed: 0      int64
# BHID           object
# FROM          float64
# TO            float64
# AU_AVG_GT     float64
# dtype: object
# Unnamed: 0      int64
# BHID           object
# FROM          float64
# TO            float64
# LITHO_DESC     object
# dtype: object

# %% [markdown]
# ###  Clean a bit the data

# %%
# plot collars as points
plt.plot (collar['XCOLLAR'],collar['YCOLLAR'], '.')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Collars')
plt.show()

# %%
# find some undesired underground drillholes
# visualize drillholes with problems
print survey[(survey['DIP']<=0) & (survey['AT']==0)]

# make list of bad drillholes
bad = survey['BHID'][(survey['DIP']<=0) & (survey['AT']==0)].unique()
print bad
# Out:
#       Unnamed: 0   BHID  AT    AZ  DIP
# 2942       20493  18809   0  2.31   -0
# 2944       20496  18810   0  2.31   -0
# 2946       20498  18811   0  2.31   -0
# 2949       20501  18812   0  2.31   -0
# 2952       20504  18813   0  2.31   -0
# 2956       20508  18814   0  2.31   -0
# 2960       20516  18816   0  2.31   -0
# 2962       20518  18817   0  2.31   -0
# 2964       20520  18818   0  2.31   -0
# 2965       20521  18819   0  2.31   -0
# 3017       20576  18846   0  2.31   -0
# 3018       20577  18848   0  2.31   -0
# 3019       20579  18851   0  2.31   -0
# 3020       20580  18852   0  2.31   -0
# 3021       20581  18856   0  2.31   -0
# 3022       20582  18857   0  2.31   -0
# 3023       20583  18858   0  2.31   -0
# 3024       20584  18859   0  2.31   -0
# 3654       54198   M-72   0  2.31  -90
# ['18809' '18810' '18811' '18812' '18813' '18814' '18816' '18817' '18818'
#  '18819' '18846' '18848' '18851' '18852' '18856' '18857' '18858' '18859'
#  'M-72']

# %%
#remove bad drillholes 
collar = collar[~collar['BHID'].isin(bad)]

# %%
# more cleanup
#Remove what is not in collar
survey = survey[survey['BHID'].isin(collar['BHID'].values)]
assay = assay[assay['BHID'].isin(collar['BHID'].values)]
litho = litho[litho['BHID'].isin(collar['BHID'].values)]

# %%
#save "clean" data
collar.to_csv('collar_clean.csv')
survey.to_csv('survey_clean.csv')
assay.to_csv('assay_clean.csv')
litho.to_csv('litho_clean.csv')

# %% [markdown]
# ### Create drillhole object

# %%
from pygslib.drillhole import *

# %%
#create database
mydholedb=Drillhole(collar=collar,survey=survey)
mydholedb.addtable(assay, 'assay' ,overwrite = False)
mydholedb.addtable(litho, 'litho', overwrite = False)
# Out:
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! Collar table without LENGTH field
#   from ipykernel import kernelapp as app

# %%
#validate
mydholedb.validate()
# Out:
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 10399. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 11241. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 11242. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 11263. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 11264. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 11265. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 1135. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 1136. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17935. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17939. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17942. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17950. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17952. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17956. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17976. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17977. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17980. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17981. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17982. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17983. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17984. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17985. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17986. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17987. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 17988. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18007. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18008. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18009. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18010. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18019. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18020. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18024. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18028. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18033. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18034. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18035. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18036. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18037. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18038. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18050. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18051. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18055. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18056. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18071. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18079. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18080. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18104. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18106. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18108. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18113. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18114. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18116. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18135. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18163. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18328. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18349. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18485. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18501. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18528. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18600. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18620. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18673. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18699. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18704. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18709. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18710. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18793. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18797. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18830. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18839. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18840. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 18843. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 197. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2092. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2093. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2094. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2095. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2096. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2097. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2098. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2099. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2100. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2192. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2193. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2194. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2211. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2212. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2213. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2401. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2402. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2403. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2404. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2405. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2406. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2412. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2413. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2422. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2423. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2424. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2425. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2426. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2427. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2586. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2587. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2588. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2589. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 2590. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 3. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 527. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 529. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 531. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 532. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 534. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 537. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 543. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 545. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 640. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 641. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 642. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 643. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 644. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 649. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 650. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 756. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 773. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: 9. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: B-479. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3090-1. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3120-1. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3120-2. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3135-1. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3135-2. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3195-1. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3195-2. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3210-15. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3255-14. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3255-15. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3420-10. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3480-4. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-3480-5. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: CE-5295-7. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: E-001. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: E-002. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: E-003. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: E-003A. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: E-004. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: L14225A. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: M-68. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: M-69. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: M-70. This will produce error at desurvey
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: ! survey with one value at BHID: SpecialG. This will produce error at desurvey
#   from ipykernel import kernelapp as app

# %%
# fixing the issue of single interval at survey table
mydholedb.fix_survey_one_interval_err(900.)

# %%
#validate table assay
mydholedb.validate_table('assay')
# Out:
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 10398 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 10399 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 11241 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 11242 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 11263 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 11264 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 11265 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 17606 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 17984 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 17994 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18010 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18035 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18055 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18075 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18101 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18104 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18170 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18247 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID B-479 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID CE-3135-2 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID CE-5295-7 not at table assay
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID SpecialG not at table assay
#   from ipykernel import kernelapp as app

# %%
#validate table litho
mydholedb.validate_table('litho')
# Out:
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID 18843A not at table litho
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID CE-5295-7 not at table litho
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID G-8 not at table litho
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID M-68 not at table litho
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID M-69 not at table litho
#   from ipykernel import kernelapp as app
# /home/adrian/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Info : collar BHID M-70 not at table litho
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Work around litho code

# %%
# see lithocode list
lclass = mydholedb.table['litho']['LITHO_DESC'].unique()
lclass
# Out:
# array(['Casing', 'Early Diorite', 'Felsic to Intermediate Dykes',
#        'Shear Zone', 'Intermediate to Ultramafic Volcanics',
#        'Indifferenciated Tuffs', 'No Litho', 'Diorite', 'Diabase',
#        'Quartz-Tourmaline Veins', 'Granodiorite', 'Fault', 'Mafic Dykes'], dtype=object)

# %%
# create litho ID numeric
mydholedb.table['litho']['lithoID']=np.NaN

i=0
for l in lclass: 
    i+=1
    mydholedb.table['litho'].loc[litho.LITHO_DESC==l,'lithoID']=i
    print i, l
# Out:
# 1 Casing
# 2 Early Diorite
# 3 Felsic to Intermediate Dykes
# 4 Shear Zone
# 5 Intermediate to Ultramafic Volcanics
# 6 Indifferenciated Tuffs
# 7 No Litho
# 8 Diorite
# 9 Diabase
# 10 Quartz-Tourmaline Veins
# 11 Granodiorite
# 12 Fault
# 13 Mafic Dykes

# %%
# merge some types
mydholedb.table['litho'].loc[mydholedb.table['litho']['lithoID']==7, 'lithoID'] = 0 # no litho equal to zero
mydholedb.table['litho'].loc[mydholedb.table['litho']['lithoID']==8, 'lithoID'] = 2 # merge Diorite, Early Diorite
mydholedb.table['litho'].loc[mydholedb.table['litho']['lithoID']==12, 'lithoID'] = 4 # merge Fault, Shear Zone

# %%
# see table
mydholedb.table['litho'][['lithoID', 'LITHO_DESC']].drop_duplicates()
# Out:
#       lithoID                            LITHO_DESC
# 0           1                                Casing
# 1           2                         Early Diorite
# 2           3          Felsic to Intermediate Dykes
# 3           4                            Shear Zone
# 5           5  Intermediate to Ultramafic Volcanics
# 10          6                Indifferenciated Tuffs
# 25          0                              No Litho
# 72          2                               Diorite
# 121         9                               Diabase
# 509        10               Quartz-Tourmaline Veins
# 720        11                          Granodiorite
# 1285        4                                 Fault
# 8162       13                           Mafic Dykes

# %%
# see results
mydholedb.table['litho'].head()
# Out:
#    Unnamed: 0   BHID   FROM     TO                    LITHO_DESC  lithoID
# 0          14     10   0.00   5.48                        Casing        1
# 1          15     10   5.48  25.90                 Early Diorite        2
# 2          16     10  25.90  28.95  Felsic to Intermediate Dykes        3
# 3          17     10  28.95  39.92                    Shear Zone        4
# 4         566  10165   0.00   3.65                        Casing        1

# %% [markdown]
# <div class="alert alert-info">
#     **Note**: The litho external table **is not** sharing memory with the litho table in the drillhole database.
# </div>

# %%
# data is shared in memory?
print id(mydholedb.table['litho'])
print id(litho)
print 'data is shared in memory? ', id(litho)== id(mydholedb.table['litho'])
# Out:
# 139967347194576
# 139967266835728
# data is shared in memory?  False

# %% [markdown]
# ### Merge tables
#
# Merging table will split interval from to tables in order to make FROM-TO equal in each interval. If the two tables have the same field, example ``Au`` and ``Au`` a prefix will be added and the result will have ``Au_A`` and ``Au_B``. In addition a new column with key ``_merge`` will be created to denote what interval are  in both tables, in the left table (A) or in the right table (B)

# %%
# first add gaps
gap_assay,overlap_assay = mydholedb.add_gaps(table_name='assay', new_table_name='assay_no_gaps')
gap_litho,overlap_litho = mydholedb.add_gaps(table_name='litho', new_table_name='litho_no_gaps')

# review errors 
print len(gap_assay),len(overlap_assay)
print len(gap_litho),len(overlap_litho)
# Out:
# 5043 4
# 0 0

# %%
# see overlaps
print overlap_assay
# Out:
# [4042, 32648, 20514, 20515]

# %%
# see where is this overlap
mydholedb.table['assay'][mydholedb.table['assay']['_id0']>4040].head()

# note that at _id0 = 4042 TO is 43. and at _id0 = 4043 FROM is 14... 
# for now we will ignore this but we may see how this was fixed in the table without gaps
# Out:
#       Unnamed: 0   BHID      FROM        TO  AU_AVG_GT  _id0
# 4041      104246  16707  18.53184  19.32432     0.1540  4041
# 4042      104247  16708  12.19200  43.28160     3.2055  4042
# 4043      104248  16708  14.29512  15.05712     8.0740  4043
# 4044      104249  16708  18.10512  18.95856     1.2170  4044
# 4045      104250  16708  21.54936  22.03704     0.1540  4045

# %%
# see where is this overlap
mydholedb.table['assay_no_gaps'][mydholedb.table['assay_no_gaps']['_id0']>4040].head()

# note that the overlap was truncated to TO=14.29
# Out:
#        BHID      FROM        TO  _id0  Unnamed: 0  AU_AVG_GT
# 3847  16707  18.53184  19.32432  4041      104246     0.1540
# 3786  16708  12.19200  14.29512  4042      104247     3.2055
# 3787  16708  14.29512  15.05712  4043      104248     8.0740
# 3789  16708  18.10512  18.95856  4044      104249     1.2170
# 3791  16708  21.54936  22.03704  4045      104250     0.1540

# %% [markdown]
# ### Merging tables
#
# <div class="alert alert-warning">
#     **Warning**: The function merge was designed to work with drillholes without gaps and overlap. Don't use merge without add_gaps first.
# </div>
#
# We will merge assay and litho table in order to be able to do some exploratory analysis.

# %%
mydholedb.merge(table_A = 'assay_no_gaps', table_B = 'litho_no_gaps', new_table_name = 'dhole',
                          overwrite =False, tol=0.01, clean=True)

# %%
mydholedb.table['dhole'].head()
# Out:
#   BHID      FROM        TO  _id0  _id1  Unnamed: 0  AU_AVG_GT  \
# 0   10   0.00000   5.48000     0     0         NaN        NaN
# 1   10   5.48000  25.90000     0     1         NaN        NaN
# 2   10  25.90000  27.91968     0     2         NaN        NaN
# 3   10  27.91968  29.04444     1     2      137823      0.005
# 4   10  29.04444  30.02280     2     3      137824      0.029
#
#    Unnamed: 0__tmp__                            LITHO_DESC  lithoID
# 0              51770                                Casing        1
# 1              51771          Felsic to Intermediate Dykes        3
# 2              51772  Intermediate to Ultramafic Volcanics        5
# 3              51772  Intermediate to Ultramafic Volcanics        5
# 4              51773          Felsic to Intermediate Dykes        3

# %% [markdown]
# ### Some quick stats
#
# This is to show what you can do with the merged table, but not a demonstration on exploratory data analysis

# %%
# histograms of Au by lithology
mydholedb.table['dhole']['AU_AVG_GT'].hist(by=mydholedb.table['dhole']['LITHO_DESC'], bins=40, figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4cab345750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4cab3f29d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4cab291710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4cab2088d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca79d2390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca794a850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca797ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca78a6410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca781f7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca77dec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca7755990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca76bd890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca763f7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca75b8790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca7593b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4ca750dd50>]], dtype=object)

# %% [markdown]
# ### Zero length intervals?
#
# <div class="alert alert-warning">
#     **Warning**: Merging produces zero (or almost zero) length intervals.
# </div>
#
# **TODO:** Build a function to remove zero length interval

# %%
mydholedb.table['dhole'][mydholedb.table['dhole']['TO']-mydholedb.table['dhole']['FROM']<0.01]
# Out:
#             BHID       FROM         TO   _id0   _id1  Unnamed: 0  AU_AVG_GT  \
# 249        10402  110.18400  110.03280    194     72      137772    0.00250
# 255        10402  114.63380  114.60480    200     74      137778    0.00250
# 276        10416   46.93720   46.93920    220     77      137798    0.04300
# 335        10422   70.09960   70.10400    262     97      137628    0.00250
# 384        10422  367.79820  367.61928    303    109      137669    0.01000
# 572        11577   88.32692   88.33104    441    176      137495    1.35400
# 586        11577   97.71608   97.68840    455    177      137509    0.04500
# 744        11579   64.96808   64.73952    594    201      137345    0.00250
# 1043       13614    8.57552    8.44296    798    330      138120    0.00250
# 1177       14341  218.14384  217.93200    926    365      140612    0.01000
# 1523       14344  160.81240  160.78200   1244    430      133170    0.01700
# 1857       14400  194.65952  194.64528   1563    478      133430    0.01500
# 1902       14400  259.33856  259.32384   1608    481      133475    0.02100
# 2004       14972  103.82576  103.81488   1702    501      133695    0.03400
# 2036       14972  193.33420  193.13042   1728    510      146455    0.02550
# 2583       14974  158.79848  158.73984   2266    561      150046    0.01000
# 4133       15273   66.12316   66.05016   3773    749      132021    0.03400
# 4327       15273  308.30400  308.15280   3965    758      126071    0.05100
# 4371       15273  360.31892  360.15168   4009    766      126114    0.22300
# 4376       15273  365.07256  365.05896   4014    768      126119    0.08600
# 4466       15274  147.70468  147.58416   4098    785      127429    2.24600
# 4493       15274  196.10532  195.83400   4124    788      100307    1.37100
# 4531       15274  243.74568  243.50472   4161    794      127404    0.03400
# 4641       15275  227.02940  226.77120   4269    812      139342    0.00250
# 4680       15275  318.38988  318.21120   4301    822      139374    0.00250
# 4776       15275  483.41280  483.41280   4393    836      135637    0.02600
# 4929       15276  332.67076  332.59776   4531    863      127850    0.01700
# 5200       15277  367.40412  367.34496   4791    896      231816    0.08600
# 5297       16037   46.98220   46.93920   4874    919      233001    0.08600
# 5415       16037  297.50000  297.48480   4979    951         NaN        NaN
# ...          ...        ...        ...    ...    ...         ...        ...
# 37810       2217    7.62000    7.62000  35163   8760      142958    0.01500
# 37819       2218    9.14200    9.14400  35166   8768      142961    0.00250
# 37919         24  144.32280  144.32280  35213   8830      143006    0.01000
# 38012       2422    6.09300    6.09600  35283   8879      143075    0.32900
# 38116       2586   26.81880   26.82240  35369   8926      143161    0.00250
# 38233         27   48.84160   48.76800  35473   8964      142795    0.00250
# 39320        649    4.56860    4.57200  36415   9255      138428    0.02200
# 39526        773    5.48320    5.48640  36586   9316      130372    0.03400
# 39596       8925   88.60100   88.54440  36643   9337         NaN        NaN
# 39598       8925   90.09560   90.06840  36645   9338      104506    0.13700
# 39602       8925  111.45004  111.28248  36649   9339         NaN        NaN
# 39699          9   49.95500   49.68240  36725   9378      117094    0.03400
# 39993  CE-3120-1   15.08760   15.08760  36897   9534      125697   10.11400
# 40320      E-005   44.80560   44.80560  37145   9644      125618    1.87700
# 40336     E-005A   31.60576   31.54680  37151   9657      125624   26.29700
# 40344     E-005A   50.12072   50.07864  37159   9660      334636    0.02600
# 40549      E-033  250.29752  250.27128  37306   9744      251348    2.74300
# 40672      E-231  124.14060  124.05360  37373   9808      128229    0.03400
# 41127      E-250  155.80948  155.81376  37707   9956      344564    0.34286
# 41335      E-255   82.13940   82.14360  37874  10006      151867    7.22900
# 41360      E-255  164.74360  164.74440  37898  10009      151891    2.57000
# 41579      E-271  120.05748  119.96928  38079  10054      334519    0.02600
# 42434     L13488    0.00000    0.00000  38804  10272         NaN        NaN
# 42508     L14095   44.31608   44.25696  38859  10297       81456    0.00300
# 42542     L14095  187.14620  187.14720  38889  10303       81483    0.00300
# 42841     L14665    5.59228    5.57000  39170  10345       81661    0.00300
# 42992     L14670    0.00000    0.00304  39320  10362         NaN        NaN
# 42993     L14670    0.00304    0.00609  39321  10362       81769    0.00300
# 43007     L14670   22.00540   21.76272  39335  10367      248839    0.68600
# 43397     L14766   48.81112   48.43272  39724  10422      151625    0.00300
#
#        Unnamed: 0__tmp__                            LITHO_DESC  lithoID
# 249                51698          Felsic to Intermediate Dykes        3
# 255                51700          Felsic to Intermediate Dykes        3
# 276                51703  Intermediate to Ultramafic Volcanics        5
# 335                50193                                Casing        1
# 384                51654                               Diorite        2
# 572               113914  Intermediate to Ultramafic Volcanics        5
# 586                52169                                Casing        1
# 744               114189          Felsic to Intermediate Dykes        3
# 1043               50950  Intermediate to Ultramafic Volcanics        5
# 1177               53942  Intermediate to Ultramafic Volcanics        5
# 1523               53884  Intermediate to Ultramafic Volcanics        5
# 1857               53867                         Early Diorite        2
# 1902               53915                            Shear Zone        4
# 2004               53902  Intermediate to Ultramafic Volcanics        5
# 2036               53911  Intermediate to Ultramafic Volcanics        5
# 2583               53366          Felsic to Intermediate Dykes        3
# 4133               48763  Intermediate to Ultramafic Volcanics        5
# 4327               48772  Intermediate to Ultramafic Volcanics        5
# 4371               48780                            Shear Zone        4
# 4376               48782          Felsic to Intermediate Dykes        3
# 4466               48806                               Diorite        2
# 4493               48809          Felsic to Intermediate Dykes        3
# 4531               48815                                Casing        1
# 4641               52126          Felsic to Intermediate Dykes        3
# 4680               47879                                Casing        1
# 4776               50433  Intermediate to Ultramafic Volcanics        5
# 4929               50397  Intermediate to Ultramafic Volcanics        5
# 5200               47863  Intermediate to Ultramafic Volcanics        5
# 5297               47081                                Casing        1
# 5415               47113  Intermediate to Ultramafic Volcanics        5
# ...                  ...                                   ...      ...
# 37810              23087                          Granodiorite       11
# 37819              23095                         Early Diorite        2
# 37919              51411  Intermediate to Ultramafic Volcanics        5
# 38012              51368          Felsic to Intermediate Dykes        3
# 38116              51324  Intermediate to Ultramafic Volcanics        5
# 38233               1993                         Early Diorite        2
# 39320              52541                         Early Diorite        2
# 39526              52618  Intermediate to Ultramafic Volcanics        5
# 39596              52581          Felsic to Intermediate Dykes        3
# 39598              52582  Intermediate to Ultramafic Volcanics        5
# 39602              52583                            Shear Zone        4
# 39699              53237  Intermediate to Ultramafic Volcanics        5
# 39993              35232  Intermediate to Ultramafic Volcanics        5
# 40320              57011                                Casing        1
# 40336              57005                         Early Diorite        2
# 40344              56991          Felsic to Intermediate Dykes        3
# 40549             115970                Indifferenciated Tuffs        6
# 40672              51096  Intermediate to Ultramafic Volcanics        5
# 41127              32658  Intermediate to Ultramafic Volcanics        5
# 41335             135531                         Early Diorite        2
# 41360             135534  Intermediate to Ultramafic Volcanics        5
# 41579              59831                         Early Diorite        2
# 42434              24870          Felsic to Intermediate Dykes        3
# 42508             107319                                Casing        1
# 42542             107325          Felsic to Intermediate Dykes        3
# 42841              56079          Felsic to Intermediate Dykes        3
# 42992              42463                            Shear Zone        4
# 42993              42463                            Shear Zone        4
# 43007              42468          Felsic to Intermediate Dykes        3
# 43397              52191          Felsic to Intermediate Dykes        3
#
# [126 rows x 10 columns]

# %% [markdown]
# ### Desurvey

# %% [markdown]
# <div class="alert alert-info">
#     **Info**: Gaps may be added before desurvey.
# </div>

# %%
#desurvey
mydholedb.desurvey('dhole',warns=False, endpoints=True)

# %% [markdown]
# ### Save results

# %%
mydholedb.table['dhole'].to_csv ('../datasets/dhole_data2/dhole.csv')

# %% [markdown]
# ### Export drillholes to vtk and import in Paraview

# %%
mydholedb.export_core_vtk_line('dhole', '../datasets/dhole_data2/dhole.vtk', nanval=0, title = '')

# %% [markdown]
# After loading ``dhole.vtk`` in Paraview and changing color scales the result may be like this:
#
# <img src='figures/dholes_line.png'>

# %% [markdown]
# # Block Model

# %%
# define block parameters
xorg = 293800
yorg = 5330800
zorg = 160
dx = 20
dy = 10
dz = 10
nx = 70
ny = 70
nz = 20

# %%
# Create an empty block model
mymodel=gslib.blockmodel.Blockmodel(nx,ny,nz,xorg,yorg,zorg,dx,dy,dz)

# %%
# Creating a full block model with IJK
mymodel.create_IJK(overwrite=True)

# %%
# Calculate row, column and level indices from IJK  
mymodel.calc_ixyz_fromijk(overwrite=True)

# %%
# Calculate coordinates from indices  
mymodel.calc_xyz_fromixyz(overwrite=True)
print mymodel.bmtable.tail()
# Out:
#          IJK  IX  IY  IZ      XC       YC   ZC
# 97995  97995  65  69  19  295110  5331495  355
# 97996  97996  66  69  19  295130  5331495  355
# 97997  97997  67  69  19  295150  5331495  355
# 97998  97998  68  69  19  295170  5331495  355
# 97999  97999  69  69  19  295190  5331495  355

# %%
# mask points below surface... 

# a) load surface
topo=gslib.vtktools.loadSTL('../datasets/dhole_data2/topo_from_collar.stl')

# get id of blocks centroids below surface (using ray trace)
inside,p=gslib.vtktools.pointquering(topo, 
                                     azm=0, 
                                     dip=90, 
                                     x=mymodel.bmtable.XC.values, 
                                     y=mymodel.bmtable.YC.values, 
                                     z=mymodel.bmtable.ZC.values, 
                                     test=3)

# %%
mymodel.bmtable['AIR']= inside

# %%
# esport block to VTK for validation
mymodel.blocks2vtkRectilinearGrid('../datasets/dhole_data2/blocks')

# %% [markdown]
# <img src='figures/full-blockm.png'>

# %% [markdown]
# ## Estimate distance to data

# %%
# Create a search Neighborhood instance
mymodel.bmtable['meandis']=0
mysearch=gslib.neighborhood.Neighborhood(mymodel.bmtable['XC'].values,
                      mymodel.bmtable['YC'].values,
                      mymodel.bmtable['ZC'].values,
                      mydholedb.table['dhole']['xm'].values,
                      mydholedb.table['dhole']['ym'].values,
                      mydholedb.table['dhole']['zm'].values,
                      target_properies=mymodel.bmtable['meandis'].values,
                      data_properies=mydholedb.table['dhole']['AU_AVG_GT'].values,
                      angles=[0,0,0],
                      axis=[500,500,500],
                      leafsize=50000)

# %%
# get data around block 250

t= 250
mysearch.get_data(target=t, k=10)

print mysearch.selected_data
print mysearch.distance_data2target
# Out:
# [42404 42403 42402 42401 42400 42399 42398 42397 41435 41436]
# [ 20.72573502  21.83183194  21.88726329  21.98366745  27.9230499
#   35.03338497  42.73293851  54.65264621  56.60031118  56.85033723]

# %%
# plot data selected in 2D
from matplotlib.patches import Ellipse


fig= plt.figure(num=None, figsize=(12, 10), dpi=200, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)

plt.hold(True)
ax.plot(mydholedb.table['dhole']['xm'],
         mydholedb.table['dhole']['ym'], '.', color='g',  label = 'Data')



plt.scatter(mydholedb.table['dhole']['xm'].iloc[mysearch.selected_data],
            mydholedb.table['dhole']['ym'].iloc[mysearch.selected_data],  
            s=mysearch.distance_data2target, 
            c=mysearch.distance_data2target, alpha=1, label = 'Selected data')
plt.hold(True)

e1 = Ellipse((mymodel.bmtable['XC'][t], mymodel.bmtable['YC'][t]), width=500, height=500.,
             angle=0, linewidth=2, fill=False, zorder=2)

ax.add_patch(e1)

plt.hold(True)

plt.plot(mymodel.bmtable['XC'][t],mymodel.bmtable['YC'][t], 'r*', label= 'Target point')

plt.hold(True)


l=plt.colorbar()
l.set_label('Distance to target')
plt.legend(loc=4)
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# ### Test apply results
#
# The Neighborhood instance can apply an arbitrary function to each target node in the block. This function can be designed by the user as any thing from mean distance data - block to Kriging, or any advanced Machine Learning algorithm.
#
# In this example we show how to create an user defined function and apply this function over each block.
#
# First define a function with the following architecture:
#
# ``` python
#
# def user_function_name(self, <optional> some_parameters ):
#
#     #do something here
#
#     return [<list of values>]
#
# ```
#
# Then you can apply this function as
#
# ``my_neighborhood.apply_interpolator(interpolator,parameters={},dtypes=[float], scale=1., k=1) ``
#
# where scale and k are the expansion factor of the search ellipse and the number of samples to use. The interpolator is a function object (your user defined function), parameters is a dictionary with the parameters required by your function and dtypes is a list with the right data types of the output of your function.
#
# <br>
#
# <div class="alert alert-info">
#     **Info**: Make sure to include self as argument and to define the output as a list of values with the right dtypes.
# </div>

# %%
# we create an interpolation function, in this case the mean distance data-target

def meandist(self):
    return [np.average(self.distance_data2target)]

# %%
# now we test the apply function
# %time a=mysearch.apply_interpolator(meandist, k=100)
# Out:
# CPU times: user 46.6 s, sys: 0 ns, total: 46.6 s
# Wall time: 46.5 s

# %%
# now we test the apply function compiled in Cython
# %time a=mysearch.apply_interpolator(gslib.interpolators.meandist, k=100)
# Out:
# CPU times: user 47 s, sys: 8 ms, total: 47 s
# Wall time: 47 s

# %%
# add results to bmodel
mymodel.bmtable['dist']=a[0]

# %%
#export results
mymodel.blocks2vtkRectilinearGrid('../datasets/dhole_data2/blocks')

# %% [markdown]
# This is the result (view as a slice)
#
# <img src='figures/dist.png'>
#
# This data can be processed in paraview to extract surfaces by distance. The process is simple:
#
# - convert cell data to point data
# - do isovolume with 0 < dist < 100
# - extract surface
# - triangulate (required to export to stl)
#
# This is the output in freecad:
#
# <img src='figures/surf_100.png'>
#
#
#
# This is the output in paraview:
#
# <img src='figures/surf_100_paraview.png'>
