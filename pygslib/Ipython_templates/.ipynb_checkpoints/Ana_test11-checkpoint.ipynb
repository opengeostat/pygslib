# %% [markdown]
# ## Testing nonlinear (temporal development)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as plt
import pygslib as gslib
# %matplotlib inline
from scipy.stats import norm

# %% [markdown]
# ## Get some data ready for work and build experimental transformation

# %%
#get the raw data in gslib format into a pandas Dataframe
mydata= gslib.read_gslib_file('../datasets/cluster.dat')

z, y,f, w = gslib.nonlinear.ttable2 (mydata['Primary'].values, mydata['Declustering Weight'].values)

#fix bias? 
y = (y-y.mean())/np.sqrt(y.var())

# make sure we are within the ranges
print y.min(),y.max()
print y.mean(),y.var()
print z.min(),z.max()
print f.min(),f.max()
# Out:
# -2.68111563336 2.34784791549
# -5.07530525543e-17 1.0
# 0.06 58.32
# 0.00578201895674 0.998392891581

# %%
# extrea test to find yamin zamin

a,b =(mydata['Primary'].values, mydata['Declustering Weight'].values)

I= np.lexsort([b,a])

a=a[I]
b=b[I]

c = b/b.sum()

d= c.cumsum()

e= norm.ppf(d)

print y.mean(), y.var()

print pd.DataFrame({'z':a, 'w':b, 'd': d, 'e': e+y.mean()})
# Out:
# -5.07530525543e-17 1.0
#             d         e      w      z
# 0    0.011564 -2.271312  1.619   0.06
# 1    0.023128 -1.993048  1.619   0.06
# 2    0.033242 -1.835144  1.416   0.08
# 3    0.042878 -1.718227  1.349   0.09
# 4    0.055885 -1.590292  1.821   0.09
# 5    0.062627 -1.533087  0.944   0.10
# 6    0.071298 -1.466188  1.214   0.10
# 7    0.079484 -1.408551  1.146   0.11
# 8    0.091048 -1.334329  1.619   0.11
# 9    0.100684 -1.277666  1.349   0.16
# 10   0.113690 -1.207133  1.821   0.16
# 11   0.120919 -1.170406  1.012   0.17
# 12   0.127662 -1.137515  0.944   0.18
# 13   0.134890 -1.103569  1.012   0.19
# 14   0.143076 -1.066603  1.146   0.19
# 15   0.153190 -1.022849  1.416   0.19
# 16   0.164754 -0.975107  1.619   0.22
# 17   0.177760 -0.923933  1.821   0.24
# 18   0.186910 -0.889340  1.281   0.26
# 19   0.196060 -0.855779  1.281   0.28
# 20   0.207138 -0.816390  1.551   0.28
# 21   0.221588 -0.766841  2.023   0.31
# 22   0.228331 -0.744355  0.944   0.32
# 23   0.239895 -0.706641  1.619   0.33
# 24   0.246638 -0.685109  0.944   0.34
# 25   0.258202 -0.648900  1.619   0.34
# 26   0.272651 -0.604814  2.023   0.34
# 27   0.280358 -0.581778  1.079   0.40
# 28   0.291922 -0.547778  1.619   0.45
# 29   0.299244 -0.526577  1.025   0.46
# ..        ...       ...    ...    ...
# 110  0.913923  1.365317  0.328   6.49
# 111  0.916109  1.379365  0.306   7.53
# 112  0.918052  1.392086  0.272   7.56
# 113  0.920302  1.407104  0.315   7.71
# 114  0.923473  1.428827  0.444   7.92
# 115  0.926509  1.450272  0.425   7.94
# 116  0.929687  1.473466  0.445   8.03
# 117  0.932123  1.491790  0.341   8.34
# 118  0.935116  1.515015  0.419   8.48
# 119  0.937580  1.534771  0.345   8.71
# 120  0.940066  1.555324  0.348   8.90
# 121  0.944108  1.590228  0.566   9.01
# 122  0.947287  1.619097  0.445   9.08
# 123  0.950851  1.653162  0.499   9.08
# 124  0.956344  1.709748  0.769   9.27
# 125  0.959294  1.742548  0.413   9.42
# 126  0.961865  1.772752  0.360  10.20
# 127  0.964929  1.810997  0.429  10.27
# 128  0.967758  1.848816  0.396  11.08
# 129  0.972629  1.920921  0.682  12.74
# 130  0.974572  1.952692  0.272  15.77
# 131  0.979322  2.039940  0.665  15.77
# 132  0.981893  2.094522  0.360  17.19
# 133  0.984022  2.144955  0.298  18.64
# 134  0.985886  2.194104  0.261  18.76
# 135  0.989065  2.292601  0.445  19.44
# 136  0.991407  2.382718  0.328  20.35
# 137  0.993736  2.496904  0.326  21.08
# 138  0.996786  2.725088  0.427  22.75
# 139  1.000000       NaN  0.450  58.32
#
# [140 rows x 4 columns]

# %%
print 
#pd.DataFrame({'z': z, 'w': w, 'f': f})

# %% [markdown]
# ## Get transformation table

# %%
# we already have Z, Y

print y.mean(), y.var() # this is 0 an 1? 
print z.mean(), z.var() # this is around data mean and variance
#pd.DataFrame({'z':z,'y':y})
# Out:
# -5.07530525543e-17 1.0
# 4.35042857143 44.9242855306

# %%
# plot experimental anamorphosis function 
plt.step(y,z, label='raw or experimental')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Experimental Gaussian anamorphosis')
#plt.yscale ('log')
#plt.xscale ('log')
#plt.legend(loc=2)
plt.show()

plt.plot(y,f)
plt.show()
plt.plot(z,f)
plt.show()

# %% [markdown]
# ## Test anamorphosis

# %%
K=50
H=gslib.nonlinear.recurrentH(y=y, K=K)
# some test plot, example lack of correlation
plt.scatter(H[1,:], H[2,:])
plt.show()
plt.scatter(H[1,:], H[3,:])
plt.show()

print H.shape, y.shape

pd.DataFrame (H.T, columns=range(H.shape[0]))
# Out:
# (51, 140) (140,)
#      0         1         2         3         4         5         6         7   \
# 0     1  2.681116  4.375846  4.584438  2.356110 -1.275396 -3.546823 -2.413444
# 1     1  2.301307  3.037741  2.157116 -0.148668 -2.082388 -1.820699  0.344250
# 2     1  2.114022  2.453015  1.267890 -0.784200 -1.875433 -0.902711  1.015025
# 3     1  1.990399  2.094230  0.781446 -1.035962 -1.621091 -0.371561  1.221313
# 4     1  1.877559  1.785605  0.402592 -1.168434 -1.341188  0.038595  1.269088
# 5     1  1.794993  1.571192  0.162683 -1.214685 -1.120590  0.287678  1.232639
# 6     1  1.737778  1.428266  0.014099 -1.224664 -0.964368  0.433795  1.177755
# 7     1  1.680770  1.290462 -0.120088 -1.218493 -0.808486  0.557566  1.102719
# 8     1  1.619855  1.148293 -0.248695 -1.195876 -0.643878  0.665882  1.003800
# 9     1  1.560094  1.013915 -0.360557 -1.159327 -0.486365  0.748548  0.891675
# 10    1  1.501413  0.886882 -0.457113 -1.111220 -0.337277  0.807666  0.770593
# 11    1  1.452647  0.785018 -0.527697 -1.063125 -0.218665  0.840818  0.664095
# 12    1  1.420695  0.720099 -0.569339 -1.028053 -0.143945  0.854992  0.592374
# 13    1  1.389976  0.659046 -0.606024 -0.991930 -0.074555  0.863197  0.522515
# 14    1  1.357366  0.595697 -0.641451 -0.951231 -0.003697  0.866303  0.447868
# 15    1  1.320212  0.525352 -0.677512 -0.902198  0.073312  0.863104  0.362809
# 16    1  1.278133  0.448041 -0.712969 -0.843649  0.155470  0.851266  0.267300
# 17    1  1.232653  0.367295 -0.745063 -0.777289  0.237917  0.829291  0.166097
# 138 -0.829048 -0.359445  0.926309  0.085048 -0.941401  0.185293
# 139  0.067790  1.333369 -0.523702 -1.141933  0.901343  0.831178
#
# [140 rows x 51 columns]

# %%
# plot some H values
plt.plot(y,H[0,:], label='H0')
plt.plot(y,H[1,:], label='H1')
plt.plot(y,H[2,:], label='H2')
plt.plot(y,H[5,:], label='H5')
plt.legend()
plt.show()

# %%
for i in range(1,H.shape[0]):
    print H[i,1:].mean()
    plt.plot(i,H[i,:].mean(), 'ob')
    
plt.plot([0,K], [0,0], '-k')
plt.ylim([-1,1])
plt.show()
# Out:
# -0.0192886016788
# -0.0314809078961
# 0.0490552943416
# -0.111303149094
# -0.0548903879445
# 0.0835172573363
# 0.0449144870524
# -0.0355448092092
# -0.0280500878902
# 0.00581229149798
# 0.0107930989997
# 0.00373374969178
# 0.00309728218059
# -0.0011805912946
# -0.0121009667834
# -0.00522213116754
# 0.0162417936863
# 0.0100946683889
# -0.0164333655887
# -0.0111187972826
# 0.0139582220666
# 0.00821780536424
# -0.0101030202021
# -0.00256124811739
# 0.0059380930915
# -0.00425946634495
# -0.00221447353997
# 0.0107825518087
# -0.00065303537173
# -0.0159669725683
# 0.00254667591926
# 0.0192816314935
# -0.00357585567107
# -0.0206610258341
# 0.00399629688833
# 0.0203885918809
# -0.00413219565282
# -0.018955007982
# 0.00431021226445
# 0.0169236411364
# -0.00480985283764
# -0.0148219048177
# 0.00583153453009
# 0.0130666897979
# -0.007481317296
# -0.011924448192
# 0.00976982134696
# 0.0115016782746
# -0.0126220832475
# -0.0117589803342

# %% [markdown]
# This shows that there is some bias in H, in the first few monomials... Compare it with the reference distribution below

# %% [markdown]
# ## Fit Anamaorphosis coefficients

# %%
PCI, g=gslib.nonlinear.fit_PCI(z,y,H)

# %% [markdown]
# ### Validate PCI
#
# There are two basic validations:
#
#  - The variance calculated from PCI may be close to the experimental variance (declustered)
#  - The error of the z' fitted with hermite polynomial expansion may be close to z

# %%
# test variance
print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(PCI)
print 'Variance experimental:             ', z.var()
# Out:
# Variance from PCI:                  51.2649485207
# Variance experimental:              44.9242855306

# %%
# test the fiiting error with polynomial expansion
ze = gslib.nonlinear.expand_anamor(PCI,H,r=1) # make sure that r == 1 for point support

fit_error = z-ze

bias = fit_error[fit_error<4].mean()

#print some comparisons
print 'Mean z', z.mean()
print 'Mean ze', ze.mean()
print 'Mean er', fit_error.mean()
print 'Var z', z.var()
print 'Var ze', ze.var()
print 'Var er', fit_error.var()
print 'Bias', bias


# scaterplots of true / estimate
plt.plot(z,ze+bias, '+')
plt.show()

# error by y
plt.plot(y,fit_error-bias)
plt.show()

# plot histogram of errors
pd.DataFrame({'fit_error': fit_error-bias}).hist(bins=20)
plt.show()
# Out:
# Mean z 4.35042857143
# Mean ze 4.08841418738
# Mean er 0.262014384053
# Var z 44.9242855306
# Var ze 30.277577166
# Var er 3.04698648279
# Bias 0.120216800861

# %%
# also plot anamorphosis function 
plt.plot(y,ze,label='Z from anamorphosis')
plt.step(y,z, label='raw')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#plt.plot(rz, norm.cdf(ry))
plt.step(z,norm.cdf(y), label='experimental')
plt.plot(ze, norm.cdf(y), label='fit')
#plt.xlim(xmin=0.05)
plt.axis([0.05,10.0, 0,1])
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Using the function to transform arbitrary y values
#
# As result of some nonlinear and simulation application you may have arbitrary gaussian (Y) values you want to convert to raw (Z) values. This is partially implemented and only valid for some practical intervals.
#
# To do this is necessary to identify four set of control points:
#
#  - [yamin,zamin] admissible minimum value
#  - [ypmin,zpmin] practical minimum value
#  - [ypmax,zpmax] practical minimum value
#  - [yamax,zamin] admissible minimum value

# %%
zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax = gslib.nonlinear.ctrpoints(z,y,ze)


print 'Minimum absolute value for Y  =', yamin
print 'Maximum absolute value for Y  =', yamax
print 'Minimum absolute value for Z  =', zamin
print 'Maximum absolute value for Z  =', zamax

print 'Minimum practical value for Y =', ypmin
print 'Maximum practical value for Y =', ypmax
print 'Minimum practical value for Z =', zpmin
print 'Maximum practical value for Z =', zpmax
# Out:
# Minimum absolute value for Y  = -2.68111562729
# Maximum absolute value for Y  = 2.34784793854
# Minimum absolute value for Z  = 0.0599999986589
# Maximum absolute value for Z  = 58.3199996948
# Minimum practical value for Y = -0.853928625584
# Maximum practical value for Y = 2.34784793854
# Minimum practical value for Z = 0.460000008345
# Maximum practical value for Z = 58.3199996948

# %%
# also plot anamorphosis function 
plt.plot(y,ze,'.', label='Z from anamorphosis')
plt.step(y,z, '-', label='raw')
plt.plot(yamin,zamin, 'ok', label='Admissible control point')
plt.plot(yamax,zamax, 'ok')
plt.plot(ypmin,zpmin, '+r', label='Practical control point')
plt.plot(ypmax,zpmax, '+r')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#test using different Y data to fit a new Z (not in the input)
yyy=np.linspace(-5,5,4000)

ZZZ=gslib.nonlinear.Y2Z(yyy,PCI,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax, r=1)

plt.plot(yyy,ZZZ, label = 'z from y in [-5, 5]')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %%
from scipy.stats import norm
plt.plot(z, g)
plt.plot(ZZZ, norm.pdf(yyy))
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.show()

# %%
#test using different Z data to fit a new Y 
zzz=np.linspace(z.min()-1,z.max()+3,1000)

YYY=gslib.nonlinear.Z2Y_linear(zzz,ze,y,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax)

plt.plot(YYY,zzz, '.',linewidth=2.0, label = 'Y from arbitrary z')
plt.step(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %%
raw = [ 1, 2, 3, 4, 5]
gau = [-2,-1, 0, 1, 2]

plt.step (gau,raw, '-')
plt.plot (gau,raw, '-o')
