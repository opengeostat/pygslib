# %% [markdown]
# ## Testing nonlinear

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as plt
import pygslib as gslib
# %matplotlib inline
from scipy.stats import norm

# %% [markdown]
# ## Get some data ready for work

# %%
#get the raw data in gslib format into a pandas Dataframe
mydata= gslib.read_gslib_file('../datasets/cluster.dat')
transin,transout, error = gslib.__dist_transf.ns_ttable(mydata['Primary'],mydata['Declustering Weight'])
mydata['NS_Primary'] = gslib.__dist_transf.nscore(mydata['Primary'],transin,transout,getrank=False)
print 'there was any error?: ', error!=0

# this is sampling regularly the probability space
gmin=norm.cdf(transout.min())
gmax=norm.cdf(transout.max())
print gmin, gmax
g=np.linspace( gmin, gmax, 1000) 

# we get normal Y from probabilities
y=norm.ppf(g)

# and z is drow from back transfor algorithm
z,error = gslib.__dist_transf.backtr(y,transin,transout,
                                     ltail=1,utail=1,ltpar=0,utpar=60,
                                     zmin=transin.min(),zmax=transin.max(),getrank=False)

print 'there was any error?: ', error!=0, error
# make sure we are within the ranges
print mydata['NS_Primary'].min(),mydata['NS_Primary'].max()
print y.min(),y.max()
print z.min(),z.max()
print transin.min(),transin.max()
# Out:
# there was any error?:  False
# 0.00578201714828 0.998392892045
# there was any error?:  False 0
# -2.11193373101 2.94647193736
# -2.52517604828 2.94647192955
# 0.06 58.32
# 0.06 58.32

# %% [markdown]
# ## Get transformation table

# %%
# we already have Z, Y

print y.mean(), y.var() # this is 0 an 1? 
print z.mean(), z.var() # this is around data mean and variance

#pd.DataFrame({'z':z,'y':y})
# Out:
# 0.0115512932587 0.949287898713
# 2.46869452938 17.3811414334

# %%
# plot experimental anamorphosis function 
plt.step(y,z, label='raw or experimental')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Experimental Gaussian anamorphosis')
#plt.yscale ('log')
#plt.xscale ('log')
#plt.legend(loc=2)
plt.show()
pd.DataFrame({'y':y}).hist(bins=30)
plt.show()
pd.DataFrame({'z':z}).hist(bins=30)
plt.show()

# %% [markdown]
# ## Test anamorphosis

# %%
K=50
H=gslib.nonlinear.recurrentH(y=y, K=K)
# some test plot, example lack of correlation
plt.scatter(H[1,:], H[2,:])
plt.show()
plt.scatter(H[1,:], H[3,:])
plt.show()

print H.shape, y.shape

pd.DataFrame (H.T, columns=range(H.shape[0]))
# Out:
# /home/adrian/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# (51, 1000) (1000,)
#      0         1         2         3         4         5         6         7   \
# 0     1  2.525176  3.801770  3.480844  1.102443 -1.868380 -2.932499 -1.069072
# 1     1  2.468944  3.603193  3.120271  0.731430 -1.983250 -2.666702 -0.652363
# 2     1  2.419580  3.432555  2.819512  0.438338 -2.047537 -2.422681 -0.319927
# 3     1  2.375490  3.283064  2.563109  0.201104 -2.078872 -2.199650 -0.050297
# 4     1  2.335585  3.150131  2.340799  0.005475 -2.087956 -1.995861  0.171189
# 5     1  2.299086  3.030514  2.145442 -0.158225 -2.081626 -1.809370  0.354918
# 6     1  2.265414  2.921836  1.971876 -0.296827 -2.064422 -1.638319  0.508479
# 7     1  2.234130  2.822302  1.816260 -0.415305 -2.039457 -1.481028  0.637558
# 8     1  2.204892  2.730526  1.675659 -0.517382 -2.008923 -1.336015  0.746505
# 982 -1.018879  0.031515  0.998393 -0.331761 -0.889298  0.590748
# 983 -1.050932  0.189359  0.981460 -0.486034 -0.825011  0.727127
# 984 -1.060017  0.358387  0.937237 -0.643023 -0.731795  0.857184
# 985 -1.040771  0.535563  0.861165 -0.798019 -0.606471  0.974968
# 986 -0.987174  0.716347  0.748531 -0.944682 -0.446270  1.072951
# 987 -0.892631  0.894206  0.594743 -1.074612 -0.249274  1.141742
# 988 -0.750193  1.059966  0.395797 -1.176850 -0.015100  1.169806
# 989 -0.553006  1.201002  0.149073 -1.237312  0.254053  1.143247
# 990 -0.295196  1.300210 -0.145345 -1.238214  0.551794  1.045803
# 991  0.026512  1.334809 -0.482482 -1.157641  0.865069  0.859323
# 992  0.409840  1.275094 -0.848864 -0.969644  1.170394  0.565299
# 993  0.841589  1.083632 -1.216536 -0.645759  1.428144  0.148669
# 994  1.287864  0.716286 -1.533169 -0.160049  1.574139 -0.393577
# 995  1.676112  0.128983 -1.705927  0.497187  1.508196 -1.033428
# 996  1.862151 -0.698581 -1.576744  1.284219  1.082580 -1.670203
# 997  1.572536 -1.688419 -0.893718  2.017481  0.109846 -2.038960
# 998  0.332280 -2.428824  0.661235  2.136701 -1.507390 -1.519548
# 999 -2.325588 -1.413780  2.908339  0.162098 -2.946740  1.067420
#
# [1000 rows x 51 columns]

# %%
# plot some H values
plt.plot(y,H[0,:], label='H0')
plt.plot(y,H[1,:], label='H1')
plt.plot(y,H[2,:], label='H2')
plt.plot(y,H[5,:], label='H5')
plt.legend()
plt.show()

# %%
for i in range(1,H.shape[0]):
    print H[i,:].mean()
    plt.plot(i,H[i,:].mean(), 'ob')
    
plt.plot([0,K], [0,0], '-k')
plt.ylim([-1,1])
plt.show()
# Out:
# -0.0115512932587
# -0.0357645197707
# -0.0217383691788
# -0.0432100542768
# 0.00279648732475
# 0.00726093796781
# 0.0130605843475
# 0.0153855459041
# -0.013103646864
# -0.0155834692151
# 0.00369006127755
# 0.00605496386938
# 0.00615826989384
# 0.0030242669595
# -0.0111151220957
# -0.00757494386794
# 0.0102066870554
# 0.00766942624213
# -0.0052502286723
# -0.00509062177181
# -0.000990104030606
# 0.00173014837313
# 0.00612270353155
# 0.00112028720005
# -0.00876073358656
# -0.00288378585036
# 0.0086016183283
# 0.00352633136314
# -0.00617587721073
# -0.00331031375908
# 0.00246853909171
# 0.00258618493036
# 0.00144369523363
# -0.00166197730408
# -0.00466123067806
# 0.000747790945378
# 0.00661061387463
# 4.63967295106e-05
# -0.00708325563213
# -0.000684656628161
# 0.00619184678905
# 0.00117123648679
# -0.00427825179577
# -0.00152194326397
# 0.00180401275594
# 0.00174668502644
# 0.0007525688941
# -0.00184368490916
# -0.00297748768741
# 0.00180263687187

# %% [markdown]
# This shows that there is some bias in H, in the first few monomials... Compare it with the reference distribution below

# %% [markdown]
# ## Fit Anamaorphosis coefficients

# %%
PCI, g=gslib.nonlinear.fit_PCI(z,y,H)

print PCI
# Out:
# [ 2.46869453 -3.105971    2.53536899 -1.49139327  0.56265502  0.04819995
#  -0.30114745  0.25802141 -0.08503328 -0.06637158  0.13784557 -0.10924646
#  -0.01414675  0.13239461 -0.10659478 -0.04976087  0.14504635 -0.05360127
#  -0.10373319  0.11865033  0.02241239 -0.12576689  0.05628936  0.08500923
#  -0.1042899  -0.02048811  0.11209679 -0.0427425  -0.08518581  0.08653293
#   0.03749347 -0.10246305  0.01489781  0.09109759 -0.0583592  -0.05932136
#   0.08419131  0.01711252 -0.08922554  0.02534029  0.07509697 -0.05970797
#  -0.04678789  0.08064888  0.0109553  -0.08608921  0.02558949  0.07686737
#  -0.0570352  -0.05599064  0.0792767 ]

# %% [markdown]
# ### Validate PCI
#
# There are two basic validations:
#
#  - The variance calculated from PCI may be close to the experimental variance (declustered)
#  - The error of the z' fitted with hermite polynomial expansion may be close to z

# %%
# test variance
print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(PCI)
print 'Variance experimental:             ', z.var()
# Out:
# Variance from PCI:                  19.0536113332
# Variance experimental:              17.3811414334

# %%
# test the fiiting error with polynomial expansion
ze = gslib.nonlinear.expand_anamor(PCI,H,r=1) # make sure that r == 1 for point support

fit_error = z-ze

bias = fit_error.mean()

#print some comparisons
print 'Mean z', z.mean()
print 'Mean ze', ze.mean()
print 'Mean er', fit_error.mean()
print 'Var z', z.var()
print 'Var ze', ze.var()
print 'Var er', fit_error.var()
print 'Bias', bias


# scaterplots of true / estimate
plt.plot(z,ze, '+')
plt.show()

# error by y
plt.plot(y,fit_error)
plt.show()

# plot histogram of errors
pd.DataFrame({'fit_error': fit_error}).hist(bins=20)
plt.show()
# Out:
# Mean z 2.46869452938
# Mean ze 2.41707726905
# Mean er 0.0516172603241
# Var z 17.3811414334
# Var ze 15.3764533094
# Var er 0.257212332145
# Bias 0.0516172603241

# %%
# also plot anamorphosis function 
plt.plot(y,ze,label='Z from anamorphosis')
plt.step(y,z, label='raw')
plt.plot(transout,transin, label='original data')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#plt.plot(rz, norm.cdf(ry))
plt.plot(z,norm.cdf(y), label='experimental')
plt.plot(ze, norm.cdf(y), label='fit')
plt.plot(transin,norm.cdf(transout), label='original data')
#plt.xlim(xmin=0.05)
plt.axis([0.05,10.0, 0,1])
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Using the function to transform arbitrary y values
#
# As result of some nonlinear and simulation application you may have arbitrary gaussian (Y) values you want to convert to raw (Z) values. This is partially implemented and only valid for some practical intervals.
#
# To do this is necessary to identify four set of control points:
#
#  - [yamin,zamin] admissible minimum value
#  - [ypmin,zpmin] practical minimum value
#  - [ypmax,zpmax] practical minimum value
#  - [yamax,zamin] admissible minimum value

# %%
zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax = gslib.nonlinear.ctrpoints(z,y,ze)
print 'Minimum absolute value for Y  =', yamin
print 'Maximum absolute value for Y  =', yamax
print 'Minimum absolute value for Z  =', zamin
print 'Maximum absolute value for Z  =', zamax

print 'Minimum practical value for Y =', ypmin
print 'Maximum practical value for Y =', ypmax
print 'Minimum practical value for Z =', zpmin
print 'Maximum practical value for Z =', zpmax
# Out:
# Minimum absolute value for Y  = -2.52517604828
# Maximum absolute value for Y  = 2.94647192955
# Minimum absolute value for Z  = 0.0599999986589
# Maximum absolute value for Z  = 58.3199996948
# Minimum practical value for Y = -1.17973446846
# Maximum practical value for Y = 2.94647192955
# Minimum practical value for Z = 0.172541290522
# Maximum practical value for Z = 58.3199996948

# %%
# also plot anamorphosis function 
plt.plot(y,ze,'.', label='Z from anamorphosis')
plt.plot(y,z, '+', label='raw')
plt.plot(yamin,zamin, 'ok', label='Admissible control point')
plt.plot(yamax,zamax, 'ok')
plt.plot(ypmin,zpmin, '+r', label='Practical control point')
plt.plot(ypmax,zpmax, '+r')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#test using different Y data to fit a new Z (not in the input)
yyy=np.linspace(-5,5,4000)

ZZZ=gslib.nonlinear.Y2Z(yyy,PCI,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax, r=1)

plt.plot(yyy,ZZZ, label = 'z from y in [-5, 5]')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %%
from scipy.stats import norm
plt.plot(transin,norm.pdf(transout), label='original data')
plt.plot(z, g)
plt.plot(ZZZ, norm.pdf(yyy))
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.show()

# %%
#test using different Z data to fit a new Y 
zzz=np.linspace(z.min()-1,z.max()+3,1000)

YYY=gslib.nonlinear.Z2Y_linear(zzz,ze,y,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax)

plt.plot(YYY,zzz, '.',linewidth=2.0, label = 'Y from arbitrary z')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Change of support and information effect
#
# ## Support effect
#
# To account for support effect you need to know:
#
# - point-support variance:  $Var(Zx) = γ(\infty)$
# - block-support variance: $ Var(Zv) = \gamma(\infty) − \gamma(v,v) $
#
# ## Information effect
#
# To account for information effect, in addition to the point variance and block variance, you need to know:
#
# - estimated grade variance: $ Var(Zv^*) = Var(Zv) -  \sigma^2_K - 2\mu$
# - true grade–estimated grade covariance: $Cov(Zv,Zv^*) = Var(Zv) - \sigma^2_K - \mu$
#
# Note that the information effect has two components. The smoothing due to kriging, represented by the estimated grade variance and some degree of conditional bias represented by the true grade–estimated grade covariance. Note that the amount of conditional bias can be represented as the slope of regression: $p = Cov(Zv,Zv^*) / (Cov(Zv,Zv^*)  - \mu)$

# %% [markdown]
# ## Calculating the support effect

# %%
# first we define the parameters for block covariance calculation
xsize = 5
ysize = 5
zsize = 5
nx, ny, nz = (5, 5, 5) # number of discretization points 
dx = np.linspace(0 + xsize/(2*nx), xsize-xsize/(2*nx), nx)
dy = np.linspace(0 + ysize/(2*ny), ysize-ysize/(2*ny), ny)
dz = np.linspace(0 + zsize/(2*nz), ysize-ysize/(2*nz), nz)
xv, yv, zv = np.meshgrid(dx, dy, dz)
xdb = xv.ravel() 
ydb = yv.ravel() 
zdb = zv.ravel() 

parameters_blk = { 
                'xdb'  :  xdb,       # X coordinates of discretazation points
                'ydb'  :  ydb,       # Y coordinates of discretazation points
                'zdb'  :  zdb,       # Z coordinates of discretazation points
                'it'   :  [1, 1],    # two structures: 1 spherical, 2 exponential 
                'c0'   :  [6],    # nugget,  
                'cc'   :  [10, 10],# variance of each structure 
                'aa'   :  [30, 60],  # parameter a (or range) mayor direction 
                'aa1'  :  [30, 60],  # parameter a (or range) semimayor direction 
                'aa2'  :  [30, 60],   # parameter a (or range) minor direction
                'ang1'   : [0, 0],   # Rotation angles per structure  
                'ang2'   : [0, 0],              
                'ang3'   : [0, 0]}       
      


unbias, blk_var=gslib.__block_covariance.block_covariance(**parameters_blk)

print 'var(Zx)=', blk_var
print 'unbias:', unbias
print 'f:', blk_var/unbias
# Out:
# var(Zx)= 16.979510753
# unbias: 26.0
# f: 0.653058105883

# %%
# now we can calculate r
r = gslib.nonlinear.get_r (Var_Zv=blk_var,PCI= PCI)
print r
# Out:
# 0.96874409001

# %%
# see the impact in the CDF (this time we plot z from anamorphosis)
yi=np.linspace(-3.5,3.5,4000)
H_yi = gslib.nonlinear.recurrentH(y=yi, K=K)
zp= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=1) 
zr= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=r) 

plt.plot(y,z,'k', label = 'experimental')
plt.plot(yi,zp, label = 'point')
plt.plot(yi,zr, label = 'block')

plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Calculating information effect parameters

# %% [markdown]
# Here we assume some arbitrary numbers. In practice you may do kriging in a panel with dummy future data, for example, blast holes.
#
# $ \sigma^2_K = 2 $
#
# and
#
# $ \mu = 0.5 $
#
# Then
#
# $ Var(Zv^*) = Var(Zv) -  \sigma^2_K - 2\mu$
# $ = Var(Zv) -  2 - 1 $
#
# $Cov(Zv,Zv^*) = Var(Zv) - \sigma^2_K - \mu$
# $ = Var(Zv) - 2 - 0.5$

# %%
blk_e_var= blk_var - 2. -2*0.5
blk_te_covar= blk_var - 2. -0.5
print 'Var(Zv*)=   ', blk_e_var
print 'Cov(Zv,Zv*)=', blk_te_covar
# Out:
# Var(Zv*)=    13.979510753
# Cov(Zv,Zv*)= 14.479510753

# %%
# now we can calculate s and ro
s = gslib.nonlinear.get_r (Var_Zv=blk_e_var,PCI= PCI)
ro = gslib.nonlinear.get_ro(Covar_ZvZv=blk_te_covar, PCI= PCI, r=r, s=s)
print 'r   = ', r
print 's   = ', s
print 'ro  = ', ro
print 's*ro= ', s*ro
# Out:
# r   =  0.96874409001
# s   =  0.912320584058
# ro  =  0.96303836504
# s*ro=  0.878599723664

# %%
# see the impact in the CDF (this time we plot z from anamorphosis)
zs= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=s*r) 

plt.plot(y,z,'k', label = 'experimental')
plt.plot(yi,zp, label = 'point')
plt.plot(yi,zr, label = 'block')
plt.plot(yi,zs, label = 'block*') # verify this

plt.legend(loc=2)
plt.show()
