# %% [markdown]
# ## Testing nonlinear

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as plt
import pygslib as gslib
# %matplotlib inline
from scipy.stats import norm

# %% [markdown]
# ## Get some data ready for work

# %%
#get the raw data in gslib format into a pandas Dataframe
mydata= gslib.read_gslib_file('../datasets/cluster.dat')
transin,transout, error = gslib.__dist_transf.ns_ttable(mydata['Primary'],mydata['Declustering Weight'])
mydata['NS_Primary'] = gslib.__dist_transf.nscore(mydata['Primary'],transin,transout,getrank=False)
print 'there was any error?: ', error!=0

# this is sampling regularly the probability space
y=np.linspace( transout.min(), transout.max(), 1000) 

# and z is drow from back transfor algorithm
z,error = gslib.__dist_transf.backtr(y,transin,transout,
                                     ltail=1,utail=1,ltpar=0,utpar=60,
                                     zmin=transin.min(),zmax=transin.max(),getrank=False)

print 'there was any error?: ', error!=0, error
# make sure we are within the ranges
print mydata['NS_Primary'].min(),mydata['NS_Primary'].max()
print y.min(),y.max()
print z.min(),z.max()
print transin.min(),transin.max()
# Out:
# there was any error?:  False
# there was any error?:  False 0
# -2.11193373101 2.94647193736
# -2.52517604828 2.94647192955
# 0.06 58.32
# 0.06 58.32

# %% [markdown]
# ## Get transformation table

# %%
# we already have Z, Y

print y.mean(), y.var() # this is 0 an 1? 
print z.mean(), z.var() # this is around data mean and variance


pd.DataFrame({'z':z,'y':y})
# Out:
# 0.210647940636 2.49990578286
# 6.87439665127 125.668204339
#             y          z
# 0   -2.525176   0.060000
# 1   -2.519699   0.060000
# 2   -2.514222   0.060000
# 3   -2.508745   0.060000
# 4   -2.503268   0.060000
# 5   -2.497790   0.060000
# 6   -2.492313   0.060000
# 7   -2.486836   0.060000
# 8   -2.481359   0.060000
# 9   -2.475882   0.060000
# 10  -2.470405   0.060000
# 11  -2.464928   0.060000
# 12  -2.459451   0.060000
# 13  -2.453973   0.060000
# 14  -2.448496   0.060000
# 15  -2.443019   0.060000
# 16  -2.437542   0.060000
# 17  -2.432065   0.060000
# 18  -2.426588   0.060000
# 19  -2.421111   0.060000
# 20  -2.415634   0.060000
# 21  -2.410156   0.060000
# 22  -2.404679   0.060000
# 23  -2.399202   0.060000
# 24  -2.393725   0.060000
# 25  -2.388248   0.060000
# 26  -2.382771   0.060000
# 27  -2.377294   0.060000
# 28  -2.371817   0.060000
# 29  -2.366339   0.060000
# ..        ...        ...
# 970  2.787635  42.277202
# 971  2.793112  42.830402
# 972  2.798590  43.383602
# 973  2.804067  43.936802
# 974  2.809544  44.490002
# 975  2.815021  45.043202
# 976  2.820498  45.596401
# 977  2.825975  46.149601
# 978  2.831452  46.702801
# 979  2.836929  47.256001
# 980  2.842407  47.809201
# 981  2.847884  48.362401
# 982  2.853361  48.915601
# 983  2.858838  49.468801
# 984  2.864315  50.022001
# 985  2.869792  50.575201
# 986  2.875269  51.128401
# 987  2.880746  51.681601
# 988  2.886224  52.234801
# 989  2.891701  52.788001
# 990  2.897178  53.341201
# 991  2.902655  53.894401
# 992  2.908132  54.447600
# 993  2.913609  55.000800
# 994  2.919086  55.554000
# 995  2.924563  56.107200
# 996  2.930041  56.660400
# 997  2.935518  57.213600
# 998  2.940995  57.766800
# 999  2.946472  58.320000
#
# [1000 rows x 2 columns]

# %%
# plot experimental anamorphosis function 
plt.plot(y,z, label='raw or experimental')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Experimental Gaussian anamorphosis')
#plt.yscale ('log')
#plt.xscale ('log')
#plt.legend(loc=2)
plt.show()
pd.DataFrame({'y':y}).hist(bins=30)
plt.show()
pd.DataFrame({'z':z}).hist(bins=30)
plt.show()

# %% [markdown]
# ## Test anamorphosis

# %%
K=50
H=gslib.nonlinear.recurrentH(y=y, K=K)
# some test plot, example lack of correlation
plt.scatter(H[1,:], H[2,:])
plt.show()
plt.scatter(H[1,:], H[3,:])
plt.show()

print H.shape, y.shape

pd.DataFrame (H.T, columns=range(H.shape[0]))
# Out:
# (51, 1000) (1000,)
#      0         1         2         3         4         5         6         7   \
# 0     1  2.525176  3.801770  3.480844  1.102443 -1.868380 -2.932499 -1.069072
# 1     1  2.519699  3.782231  3.444871  1.064510 -1.881649 -2.907343 -1.026759
# 2     1  2.514222  3.762735  3.409083  1.026971 -1.894456 -2.882012 -0.984812
# 3     1  2.508745  3.743282  3.373479  0.989822 -1.906806 -2.856513 -0.943233
# 4     1  2.503268  3.723871  3.338060  0.953062 -1.918703 -2.830850 -0.902024
# 5     1  2.497790  3.704502  3.302825  0.916689 -1.930152 -2.805031 -0.861189
# 6     1  2.492313  3.685176  3.267773  0.880702 -1.941159 -2.779062 -0.820729
# 7     1  2.486836  3.665892  3.232905  0.845097 -1.951726 -2.752948 -0.780646
# 8     1  2.481359  3.646651  3.198219  0.809873 -1.961860 -2.726695 -0.740943
# 9     1  2.475882  3.627452  3.163716  0.775028 -1.971565 -2.700308 -0.701621
# 10    1  2.470405  3.608295  3.129394  0.740560 -1.980846 -2.673795 -0.662683
# 11    1  2.464928  3.589181  3.095254  0.706467 -1.989706 -2.647159 -0.624130
# 12    1  2.459451  3.570109  3.061295  0.672747 -1.998152 -2.620408 -0.585963
# 13    1  2.453973  3.551080  3.027517  0.639398 -2.006186 -2.593546 -0.548185
# 14    1  2.448496  3.532093  2.993919  0.606418 -2.013815 -2.566579 -0.510797
# 15    1  2.443019  3.513149  2.960502  0.573805 -2.021042 -2.539513 -0.473800
# 16    1  2.437542  3.494247  2.927263  0.541557 -2.027871 -2.512352 -0.437196
# 17    1  2.432065  3.475387  2.894204  0.509672 -2.034308 -2.485102 -0.400987
# 18    1  2.426588  3.456570  2.861323  0.478149 -2.040357 -2.457768 -0.365173
# 19    1  2.421111  3.437795  2.828621  0.446984 -2.046022 -2.430356 -0.329756
# 20    1  2.415634  3.419063  2.796097  0.416177 -2.051307 -2.402871 -0.294736
# 21    1  2.410156  3.400373  2.763750  0.385725 -2.056217 -2.375317 -0.260116
# 22    1  2.404679  3.381726  2.731580  0.355627 -2.060757 -2.347699 -0.225895
# 23    1  2.399202  3.363121  2.699587  0.325880 -2.064930 -2.320023 -0.192074
# 24    1  2.393725  3.344558  2.667771  0.296482 -2.068740 -2.292294 -0.158655
# 25    1  2.388248  3.326038  2.636130  0.267432 -2.072193 -2.264516 -0.125639
# 26    1  2.382771  3.307560  2.604665  0.238728 -2.075292 -2.236694 -0.093025
# 27    1  2.377294  3.289125  2.573374  0.210367 -2.078042 -2.208832 -0.060815
# 25  -0.450571  1.262757  0.885648 -0.944239 -1.198718  0.529883
# 26  -0.397821  1.278515  0.837931 -0.976943 -1.161884  0.575599
# 27  -0.345222  1.292315  0.789658 -1.007825 -1.123830  0.619864
# 28  -0.292840  1.304166  0.740904 -1.036866 -1.084627  0.662634
# 29  -0.240742  1.314075  0.691742 -1.064050 -1.044347  0.703864
# ..        ...       ...       ...       ...       ...       ...
# 970  0.434365 -2.411520  0.550849  2.164628 -1.407227 -1.588100
# 971  0.350502 -2.426104  0.641683  2.142003 -1.489796 -1.531997
# 972  0.264869 -2.437539  0.733006  2.115922 -1.571431 -1.472715
# 973  0.177554 -2.445761  0.824699  2.086368 -1.652000 -1.410291
# 974  0.088645 -2.450710  0.916639  2.053330 -1.731369 -1.344769
# 975 -0.001763 -2.452329  1.008702  2.016800 -1.809404 -1.276199
# 976 -0.093573 -2.450562  1.100763  1.976776 -1.885972 -1.204635
# 977 -0.186685 -2.445361  1.192693  1.933261 -1.960938 -1.130136
# 978 -0.280996 -2.436677  1.284362  1.886262 -2.034169 -1.052767
# 979 -0.376398 -2.424470  1.375639  1.835792 -2.105532 -0.972597
# 980 -0.472783 -2.408701  1.466392  1.781867 -2.174893 -0.889702
# 981 -0.570036 -2.389334  1.556484  1.724511 -2.242121 -0.804161
# 982 -0.668043 -2.366340  1.645782  1.663751 -2.307085 -0.716060
# 983 -0.766685 -2.339694  1.734147  1.599619 -2.369654 -0.625489
# 984 -0.865840 -2.309373  1.821443  1.532154 -2.429700 -0.532543
# 985 -0.965386 -2.275361  1.907532  1.461399 -2.487097 -0.437323
# 986 -1.065195 -2.237646  1.992273  1.387402 -2.541719 -0.339933
# 987 -1.165139 -2.196220  2.075529  1.310218 -2.593442 -0.240483
# 988 -1.265088 -2.151081  2.157160  1.229904 -2.642146 -0.139089
# 989 -1.364907 -2.102232  2.237026  1.146526 -2.687711 -0.035868
# 990 -1.464464 -2.049678  2.314988  1.060153 -2.730023  0.069055
# 991 -1.563620 -1.993434  2.390908  0.970860 -2.768966  0.175551
# 992 -1.662238 -1.933515  2.464646  0.878727 -2.804432  0.283489
# 993 -1.760177 -1.869946  2.536066  0.783839 -2.836312  0.392731
# 994 -1.857297 -1.802753  2.605031  0.686287 -2.864502  0.503137
# 995 -1.953455 -1.731969  2.671405  0.586168 -2.888903  0.614562
# 996 -2.048508 -1.657634  2.735055  0.483580 -2.909418  0.726856
# 997 -2.142311 -1.579790  2.795847  0.378631 -2.925954  0.839869
# 998 -2.234720 -1.498487  2.853652  0.271432 -2.938423  0.953443
# 999 -2.325588 -1.413780  2.908339  0.162098 -2.946740  1.067420
#
# [1000 rows x 51 columns]

# %%
# plot some H values
plt.plot(y,H[0,:], label='H0')
plt.plot(y,H[1,:], label='H1')
plt.plot(y,H[2,:], label='H2')
plt.plot(y,H[5,:], label='H5')
plt.legend()
plt.show()

# %%
for i in range(1,H.shape[0]):
    print H[i,:].mean()
    plt.plot(i,H[i,:].mean(), 'ob')
    
plt.plot([0,K], [0,0], '-k')
plt.ylim([-1,1])
plt.show()
# Out:
# -0.210647940636
# 1.09196968466
# -0.390776561954
# -0.0712394901072
# 0.0593030628285
# -0.426175820335
# 0.231339871736
# 0.337753339453
# -0.242314987479
# -0.0556630680133
# 0.0773718932654
# -0.157170640003
# 0.103641904265
# 0.22027921565
# -0.201225474067
# -0.163987129474
# 0.192547681367
# 0.0557202658455
# -0.106595669939
# 0.0451521403484
# -0.00784144941682
# -0.105109912866
# 0.106316783148
# 0.116587647402
# -0.161244211066
# -0.0898296415181
# 0.164523228243
# 0.0430509648272
# -0.123867124717
# 0.00554422252925
# 0.0563600748062
# -0.042603723845
# 0.0181286319158
# 0.0614385478057
# -0.082119893728
# -0.0615868647593
# 0.12366343621
# 0.0470889959389
# -0.137471136506
# -0.0243209417358
# 0.124457737654
# -4.29095111296e-06
# -0.0902557731299
# 0.020318967535
# 0.0432658832879
# -0.0330418159734
# 0.00729641644754
# 0.0368151253055
# -0.0530378919779
# -0.0322708400659

# %% [markdown]
# This shows that there is some bias in H, in the first few monomials... Compare it with the reference distribution below

# %% [markdown]
# ## Fit Anamaorphosis coefficients

# %%
PCI, g=gslib.nonlinear.fit_PCI(z,y,H)

# %% [markdown]
# ### Validate PCI
#
# There are two basic validations:
#
#  - The variance calculated from PCI may be close to the experimental variance (declustered)
#  - The error of the z' fitted with hermite polynomial expansion may be close to z

# %%
# test variance
print 'Variance from PCI:                 ', gslib.nonlinear.var_PCI(PCI)
print 'Variance experimental:             ', z.var()
# Out:
# Variance from PCI:                  20.3019836604
# Variance experimental:              125.668204339

# %%
# test the fiiting error with polynomial expansion
ze = gslib.nonlinear.expand_anamor(PCI,H,r=1) # make sure that r == 1 for point support

fit_error = z-ze

bias = fit_error[fit_error<4].mean()

#print some comparisons
print 'Mean z', z.mean()
print 'Mean ze', ze.mean()
print 'Mean er', fit_error.mean()
print 'Var z', z.var()
print 'Var ze', ze.var()
print 'Var er', fit_error.var()
print 'Bias', bias


# scaterplots of true / estimate
plt.plot(z,ze+bias, '+')
plt.show()

# error by y
plt.plot(y,fit_error-bias)
plt.show()

# plot histogram of errors
pd.DataFrame({'fit_error': fit_error-bias}).hist(bins=20)
plt.show()
# Out:
# Mean z 6.87439665127
# Mean ze 11.1485805009
# Mean er -4.27418384959
# Var z 125.668204339
# Var ze 115.378446327
# Var er 1.34815715256
# Bias -4.27418384959

# %%
# also plot anamorphosis function 
plt.plot(y,ze+bias,label='Z from anamorphosis')
plt.plot(y,z, label='raw')
plt.plot(transout,transin, label='original data')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#plt.plot(rz, norm.cdf(ry))
plt.plot(z,norm.cdf(y), label='experimental')
plt.plot(ze+bias, norm.cdf(y), label='fit')
plt.plot(transin,norm.cdf(transout), label='original data')
#plt.xlim(xmin=0.05)
plt.axis([0.05,10.0, 0,1])
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Using the function to transform arbitrary y values
#
# As result of some nonlinear and simulation application you may have arbitrary gaussian (Y) values you want to convert to raw (Z) values. This is partially implemented and only valid for some practical intervals.
#
# To do this is necessary to identify four set of control points:
#
#  - [yamin,zamin] admissible minimum value
#  - [ypmin,zpmin] practical minimum value
#  - [ypmax,zpmax] practical minimum value
#  - [yamax,zamin] admissible minimum value

# %%
zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax = gslib.nonlinear.ctrpoints(z,y,ze-bias)
print zamin,yamin,zamax,yamax
print zpmin,ypmin,zpmax,ypmax
# Out:
# 0.0599999986589 -2.52517604828 58.3199996948 2.94647192955
# 0.161238893867 -1.22709739208 55.5540008545 2.91908621788

# %%
# also plot anamorphosis function 
plt.plot(y,ze+bias,'.', label='Z from anamorphosis')
plt.plot(y,z, '+', label='raw')
plt.plot(yamin,zamin, 'ok', label='Admissible control point')
plt.plot(yamax,zamax, 'ok')
plt.plot(ypmin,zpmin, '+r', label='Practical control point')
plt.plot(ypmax,zpmax, '+r')
plt.xlabel('Y: Gaussian values')
plt.ylabel('Z: Raw values')
plt.title('Gaussian anamorphosis')
plt.legend(loc=2)
plt.show()

# %%
#test using different Y data to fit a new Z (not in the input)
yyy=np.linspace(-5,5,4000)

ZZZ=gslib.nonlinear.Y2Z(yyy,PCI,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax, r=1)

plt.plot(yyy,ZZZ+bias, label = 'z from y in [-5, 5]')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze+bias, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %%
from scipy.stats import norm
plt.plot(transin,norm.pdf(transout), label='original data')
plt.plot(z, g)
plt.plot(ZZZ+bias, norm.pdf(yyy))
plt.xlabel('Z')
plt.ylabel('P(Z<zi)')
plt.xscale('log')
plt.show()

# %%
#test using different Z data to fit a new Y 
zzz=np.linspace(z.min()-1,z.max()+3,1000)

YYY=gslib.nonlinear.Z2Y_linear(zzz,ze,y,zamin, yamin, zpmin, ypmin, zpmax, ypmax, zamax, yamax)

plt.plot(YYY,zzz, '.',linewidth=2.0, label = 'Y from arbitrary z')
plt.plot(y,z, label = 'Raw transformation (z)')
plt.plot(y,ze+bias, label = 'z from y in dataset (ze)')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # Change of support and information effect
#
# ## Support effect
#
# To account for support effect you need to know:
#
# - point-support variance:  $Var(Zx) = γ(\infty)$
# - block-support variance: $ Var(Zv) = \gamma(\infty) − \gamma(v,v) $
#
# ## Information effect
#
# To account for information effect, in addition to the point variance and block variance, you need to know:
#
# - estimated grade variance: $ Var(Zv^*) = Var(Zv) -  \sigma^2_K - 2\mu$
# - true grade–estimated grade covariance: $Cov(Zv,Zv^*) = Var(Zv) - \sigma^2_K - \mu$
#
# Note that the information effect has two components. The smoothing due to kriging, represented by the estimated grade variance and some degree of conditional bias represented by the true grade–estimated grade covariance. Note that the amount of conditional bias can be represented as the slope of regression: $p = Cov(Zv,Zv^*) / (Cov(Zv,Zv^*)  - \mu)$

# %% [markdown]
# ## Calculating the support effect

# %%
# first we define the parameters for block covariance calculation
xsize = 5
ysize = 5
zsize = 5
nx, ny, nz = (5, 5, 5) # number of discretization points 
dx = np.linspace(0 + xsize/(2*nx), xsize-xsize/(2*nx), nx)
dy = np.linspace(0 + ysize/(2*ny), ysize-ysize/(2*ny), ny)
dz = np.linspace(0 + zsize/(2*nz), ysize-ysize/(2*nz), nz)
xv, yv, zv = np.meshgrid(dx, dy, dz)
xdb = xv.ravel() 
ydb = yv.ravel() 
zdb = zv.ravel() 

parameters_blk = { 
                'xdb'  :  xdb,       # X coordinates of discretazation points
                'ydb'  :  ydb,       # Y coordinates of discretazation points
                'zdb'  :  zdb,       # Z coordinates of discretazation points
                'it'   :  [1, 1],    # two structures: 1 spherical, 2 exponential 
                'c0'   :  [6],    # nugget,  
                'cc'   :  [10, 10],# variance of each structure 
                'aa'   :  [30, 60],  # parameter a (or range) mayor direction 
                'aa1'  :  [30, 60],  # parameter a (or range) semimayor direction 
                'aa2'  :  [30, 60],   # parameter a (or range) minor direction
                'ang1'   : [0, 0],   # Rotation angles per structure  
                'ang2'   : [0, 0],              
                'ang3'   : [0, 0]}       
      


unbias, blk_var=gslib.__block_covariance.block_covariance(**parameters_blk)

print 'var(Zx)=', blk_var
print 'unbias:', unbias
print 'f:', blk_var/unbias
# Out:
# var(Zx)= 16.979510753
# unbias: 26.0
# f: 0.653058105883

# %%
# now we can calculate r
r = gslib.nonlinear.get_r (Var_Zv=blk_var,PCI= PCI)
print r
# Out:
# 0.951789945365

# %%
# see the impact in the CDF (this time we plot z from anamorphosis)
yi=np.linspace(-3.5,3.5,4000)
H_yi = gslib.nonlinear.recurrentH(y=yi, K=K)
zp= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=1) 
zr= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=r) 

plt.plot(y,z,'k', label = 'experimental')
plt.plot(yi,zp, label = 'point')
plt.plot(yi,zr, label = 'block')

plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Calculating information effect parameters

# %% [markdown]
# Here we assume some arbitrary numbers. In practice you may do kriging in a panel with dummy future data, for example, blast holes.
#
# $ \sigma^2_K = 2 $
#
# and
#
# $ \mu = 0.5 $
#
# Then
#
# $ Var(Zv^*) = Var(Zv) -  \sigma^2_K - 2\mu$
# $ = Var(Zv) -  2 - 1 $
#
# $Cov(Zv,Zv^*) = Var(Zv) - \sigma^2_K - \mu$
# $ = Var(Zv) - 2 - 0.5$

# %%
blk_e_var= blk_var - 2. -2*0.5
blk_te_covar= blk_var - 2. -0.5
print 'Var(Zv*)=   ', blk_e_var
print 'Cov(Zv,Zv*)=', blk_te_covar
# Out:
# Var(Zv*)=    13.979510753
# Cov(Zv,Zv*)= 14.479510753

# %%
# now we can calculate s and ro
s = gslib.nonlinear.get_r (Var_Zv=blk_e_var,PCI= PCI)
ro = gslib.nonlinear.get_ro(Covar_ZvZv=blk_te_covar, PCI= PCI, r=r, s=s)
print 'r   = ', r
print 's   = ', s
print 'ro  = ', ro
print 's*ro= ', s*ro
# Out:
# r   =  0.951789945365
# s   =  0.896265298127
# ro  =  0.962901026011
# s*ro=  0.863014775145

# %%
# see the impact in the CDF (this time we plot z from anamorphosis)
zs= gslib.nonlinear.expand_anamor(PCI,H=H_yi,r=s*r) 

plt.plot(y,z,'k', label = 'experimental')
plt.plot(yi,zp, label = 'point')
plt.plot(yi,zr, label = 'block')
plt.plot(yi,zs, label = 'block*') # verify this

plt.legend(loc=2)
plt.show()
